# %%
cd /kaggle/input/trainXX
# Out:
# /kaggle/input/trainXX

# %%
path = '/kaggle/input/trainXX'

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D,LeakyReLU,Conv2DTranspose
from keras.layers import Activation
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
from keras.initializers import RandomNormal
from keras.utils import to_categorical
from keras.layers import Input, Dense
from keras.layers import Concatenate

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,)
                                   
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(path,
                                                target_size=(28,56),
                                                class_mode = 'categorical',
                                                shuffle=True,color_mode='grayscale')
# Out:
# Found 60000 images belonging to 10 classes.

# %%
# define the discriminator model
def define_discriminator(image_shape=(28,28,1,)):
    in_image = Input(shape=image_shape)
    out_image = Input(shape=image_shape)
    init = RandomNormal(stddev=0.02)
    merged = Concatenate(axis=-1)([in_image, out_image])
    
    
    d = Conv2D(64, (3,3), kernel_initializer=init)(merged)
    d= LeakyReLU(alpha=0.2)(d)
    d = Conv2D(128, (3,3), kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
    d = MaxPooling2D(pool_size=2,strides=2)(d)
  
    d = Conv2D(196, (3,3), kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
    d = MaxPooling2D(pool_size=2,strides=2)(d)
  
    d = Conv2D(256, (3,3), kernel_initializer=init)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
    d = MaxPooling2D(pool_size=2,strides=2)(d)
  
    d = Flatten()(d)
    d = Dense(256, activation='relu')(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
  
    d = Dense(128)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
  
    d = Dense(64)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    d = Dropout(0.5)(d)
    
    d = Dense(32)(d)
    d = BatchNormalization()(d)
    d = LeakyReLU(alpha=0.2)(d)
    
    d = Dense(1)(d) 
    patch_out = Activation('sigmoid')(d)
  
    model = Model([in_image, out_image], patch_out)
    print('Compiling Discriminator')
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'], loss_weights=[0.5])
    model.summary()
    return model

# %%
def define_generator(image_shape=(28,28,1,)):
    in_image = Input(shape=image_shape)
    g = Conv2D(64, kernel_size=3, activation='relu',padding='same', input_shape=(28,28,1))(in_image)
    g = BatchNormalization()(g)
    
    g = Conv2D(128, kernel_size=3, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2D(196, kernel_size=3, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2D(256, kernel_size=3, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2D(512, kernel_size=2, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2DTranspose(512, kernel_size=3, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2DTranspose(256, kernel_size=2, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2DTranspose(128, kernel_size=3, strides=(2, 2))(g)
    g = BatchNormalization()(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = Dropout(0.25)(g)
    
    g = Conv2DTranspose(1, kernel_size=4, strides=(2, 2))(g)
    out_image = Activation('tanh')(g)
    model = Model(in_image, out_image)
    print('Compiling generator')
    model.summary()
    return model

# %%
discriminator = define_discriminator()
# Out:
# Compiling Discriminator
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 2)    0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 26, 26, 64)   1216        concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 26, 26, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 24, 24, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 24, 24, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 24, 24, 128)  0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 128)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 196)  225988      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 10, 10, 196)  784         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 10, 10, 196)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 10, 10, 196)  0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 196)    0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 3, 3, 256)    451840      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 256)    1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 3, 3, 256)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 3, 3, 256)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 256)    0           dropout_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           8256        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 64)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           2080        dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32)           128         dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            33          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           dense_5[0][0]
# ==================================================================================================
# Total params: 866,197
# Trainable params: 864,077
# Non-trainable params: 2,120
# __________________________________________________________________________________________________

# %%
generator = define_generator()
# Out:
# Compiling generator
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 196)         225988
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 6, 196)         784
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 6, 6, 196)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 196)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 256)         451840
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         524800
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 3, 3, 512)         2359808
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 6, 6, 256)         524544
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 13, 13, 128)       295040
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 28, 28, 1)         2049
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 4,466,773
# Trainable params: 4,462,669
# Non-trainable params: 4,104
# _________________________________________________________________

# %%
def define_gan(g_model, d_model, image_shape=(28,28,1,)):
    # make weights in the discriminator not trainable
    d_model.trainable = False
    # define the source image
    in_src = Input(shape=image_shape)
    # connect the source image to the generator input
    gen_out = g_model(in_src)
    # connect the source input and generator output to the discriminator input
    dis_out = d_model([in_src, gen_out])
    # src image as input, generated image and classification output
    model = Model(in_src, [dis_out, gen_out])
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss=['binary_crossentropy', 'mae'], optimizer=opt, loss_weights=[1,100])
    return model

# %%
def generate_fake_samples(g_model, image_hand, patch_shape=1):
    # generate fake instance
    X = g_model.predict(image_hand)
    # create 'fake' class labels (0)
    y = np.zeros((len(X), patch_shape))
    return X, y

# %%
def generat_real_samples( patch_shape=1):
    X,y = training_set.next()
    real_print,real_hand = X[:,:,:28],X[:,:,28:]
    real_hand = np.reshape(real_hand,[-1, 28, 28, 1])
    real_print = np.reshape(real_print,[-1, 28, 28, 1])
    real_label = np.ones((len(X), patch_shape))
    return [real_hand,real_print],real_label

# %%
I = training_set.n//training_set.batch_size
I
# Out:
# 1875

# %%
gan_model = define_gan(generator,discriminator)

# %%
for i in range(I):
    #generating real sample
    [real_hand,real_print],real_label = generat_real_samples()
    #generating fake sample
    fake_print,fake_label = generate_fake_samples(generator,real_hand)
    #update discriminator for real sample
    d_loss1 = discriminator.train_on_batch([real_hand,real_print,], real_label)
    #update discriminator for fake sample
    d_loss2 = discriminator.train_on_batch([fake_print,real_print,], fake_label)
    # update the generator
    g_loss, _, _ = gan_model.train_on_batch(real_hand, [real_label, real_print])
    #print performance
    print("epoch {}: real_loss: {}---fake_loss: {}---GAN_LOSS: {}".format(i+1, d_loss1,d_loss2,g_loss))
    if i % 10 == 0:
        #filename = '/GAN/model_%06d' % (i+1)
        #g_model.save(filename+'gan.h5')
        #generator.save(filename+'generator.h5')
        #discriminator.save(filename+'discriminator.h5')
        a = np.random.randint(1,32)
        i = real_print[a]
        j = np.reshape(i,(28,28))
        plt.subplot(1,3,1)
        plt.imshow(j,cmap='gray')
        i = real_hand[a]
        j = np.reshape(i,(28,28))
        plt.subplot(1,3,2)
        plt.imshow(j,cmap='gray')
        i = fake_print[a]
        j = np.reshape(i,(28,28))
        plt.subplot(1,3,3)
        plt.imshow(j,cmap='gray')
        plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch 1: real_loss: [0.54226565, 0.25]---fake_loss: [0.27986488, 0.65625]---GAN_LOSS: 44.43692398071289
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch 2: real_loss: [0.5150899, 0.28125]---fake_loss: [0.28301233, 0.75]---GAN_LOSS: 41.99150085449219
# epoch 3: real_loss: [0.5348879, 0.28125]---fake_loss: [0.25595233, 0.71875]---GAN_LOSS: 40.84360885620117
# epoch 4: real_loss: [0.5530624, 0.3125]---fake_loss: [0.28602403, 0.71875]---GAN_LOSS: 39.820980072021484
# epoch 5: real_loss: [0.53130627, 0.28125]---fake_loss: [0.25969878, 0.75]---GAN_LOSS: 39.02981948852539
# epoch 6: real_loss: [0.56658316, 0.3125]---fake_loss: [0.2679429, 0.78125]---GAN_LOSS: 37.03181838989258
# epoch 7: real_loss: [0.54095507, 0.21875]---fake_loss: [0.29448974, 0.75]---GAN_LOSS: 36.6141357421875
# epoch 8: real_loss: [0.55420023, 0.3125]---fake_loss: [0.27795863, 0.75]---GAN_LOSS: 35.51472854614258
# epoch 9: real_loss: [0.5203293, 0.3125]---fake_loss: [0.29558355, 0.6875]---GAN_LOSS: 34.70554733276367
# epoch 10: real_loss: [0.5326567, 0.25]---fake_loss: [0.2785837, 0.75]---GAN_LOSS: 33.37810516357422
# epoch 11: real_loss: [0.5691692, 0.3125]---fake_loss: [0.26772293, 0.71875]---GAN_LOSS: 32.91712951660156
# epoch 12: real_loss: [0.5460005, 0.28125]---fake_loss: [0.25847572, 0.75]---GAN_LOSS: 32.733341217041016
# epoch 13: real_loss: [0.5395755, 0.3125]---fake_loss: [0.25960314, 0.65625]---GAN_LOSS: 31.36318016052246
# epoch 14: real_loss: [0.5567585, 0.28125]---fake_loss: [0.28473228, 0.65625]---GAN_LOSS: 30.881147384643555
# epoch 15: real_loss: [0.53808296, 0.3125]---fake_loss: [0.29438028, 0.71875]---GAN_LOSS: 30.376937866210938
# epoch 16: real_loss: [0.5308058, 0.3125]---fake_loss: [0.2769535, 0.71875]---GAN_LOSS: 29.47652244567871
# epoch 17: real_loss: [0.5380917, 0.3125]---fake_loss: [0.28641135, 0.75]---GAN_LOSS: 29.15766143798828
# epoch 18: real_loss: [0.5214751, 0.25]---fake_loss: [0.2718603, 0.65625]---GAN_LOSS: 27.939743041992188
# epoch 19: real_loss: [0.5276526, 0.3125]---fake_loss: [0.28004283, 0.71875]---GAN_LOSS: 27.64002799987793
# epoch 20: real_loss: [0.5303812, 0.3125]---fake_loss: [0.2866763, 0.6875]---GAN_LOSS: 26.71148681640625
# epoch 21: real_loss: [0.5343711, 0.3125]---fake_loss: [0.25610507, 0.75]---GAN_LOSS: 25.620227813720703
# epoch 22: real_loss: [0.53053933, 0.21875]---fake_loss: [0.28711396, 0.71875]---GAN_LOSS: 24.030595779418945
# epoch 23: real_loss: [0.52312565, 0.21875]---fake_loss: [0.2957872, 0.6875]---GAN_LOSS: 23.877300262451172
# epoch 24: real_loss: [0.51466036, 0.34375]---fake_loss: [0.27911907, 0.71875]---GAN_LOSS: 22.04507827758789
# epoch 25: real_loss: [0.5169028, 0.28125]---fake_loss: [0.27319592, 0.75]---GAN_LOSS: 21.577816009521484
# epoch 26: real_loss: [0.51304924, 0.28125]---fake_loss: [0.2846626, 0.71875]---GAN_LOSS: 23.935834884643555
# epoch 27: real_loss: [0.5182704, 0.3125]---fake_loss: [0.2761288, 0.71875]---GAN_LOSS: 21.335493087768555
# epoch 28: real_loss: [0.52841663, 0.25]---fake_loss: [0.28931993, 0.75]---GAN_LOSS: 19.798545837402344
# epoch 29: real_loss: [0.5163655, 0.25]---fake_loss: [0.25791252, 0.75]---GAN_LOSS: 20.73665428161621
# epoch 30: real_loss: [0.5243746, 0.28125]---fake_loss: [0.2769313, 0.71875]---GAN_LOSS: 19.59560203552246
# epoch 31: real_loss: [0.5123215, 0.28125]---fake_loss: [0.2921806, 0.65625]---GAN_LOSS: 19.345020294189453
# epoch 32: real_loss: [0.51078844, 0.25]---fake_loss: [0.2815694, 0.6875]---GAN_LOSS: 18.724485397338867
# epoch 33: real_loss: [0.53026456, 0.21875]---fake_loss: [0.2729809, 0.75]---GAN_LOSS: 18.03647804260254
# epoch 34: real_loss: [0.51589227, 0.15625]---fake_loss: [0.2609219, 0.78125]---GAN_LOSS: 18.260629653930664
# epoch 35: real_loss: [0.4880775, 0.1875]---fake_loss: [0.27460533, 0.71875]---GAN_LOSS: 17.60321617126465
# epoch 36: real_loss: [0.51855445, 0.25]---fake_loss: [0.29577348, 0.65625]---GAN_LOSS: 18.179622650146484
# epoch 37: real_loss: [0.526067, 0.34375]---fake_loss: [0.28402093, 0.65625]---GAN_LOSS: 17.33738136291504
# epoch 38: real_loss: [0.51321274, 0.3125]---fake_loss: [0.28898495, 0.75]---GAN_LOSS: 16.31390380859375
# epoch 39: real_loss: [0.5069672, 0.21875]---fake_loss: [0.27194798, 0.625]---GAN_LOSS: 17.40073013305664
# epoch 40: real_loss: [0.5182966, 0.21875]---fake_loss: [0.27530268, 0.71875]---GAN_LOSS: 16.50528907775879
# epoch 41: real_loss: [0.5158371, 0.21875]---fake_loss: [0.28665024, 0.78125]---GAN_LOSS: 15.346918106079102
# epoch 42: real_loss: [0.53155625, 0.375]---fake_loss: [0.260584, 0.78125]---GAN_LOSS: 15.53528118133545
# epoch 43: real_loss: [0.5144218, 0.28125]---fake_loss: [0.28131, 0.71875]---GAN_LOSS: 14.814085960388184
# epoch 44: real_loss: [0.5154749, 0.25]---fake_loss: [0.27110747, 0.75]---GAN_LOSS: 14.5904541015625
# epoch 45: real_loss: [0.5163375, 0.25]---fake_loss: [0.27910346, 0.6875]---GAN_LOSS: 16.88409423828125
# epoch 46: real_loss: [0.52621317, 0.25]---fake_loss: [0.27050444, 0.78125]---GAN_LOSS: 16.01707649230957
# epoch 47: real_loss: [0.5046879, 0.34375]---fake_loss: [0.28427023, 0.75]---GAN_LOSS: 15.166505813598633
# epoch 48: real_loss: [0.5194918, 0.21875]---fake_loss: [0.29196241, 0.6875]---GAN_LOSS: 14.39393138885498
# epoch 49: real_loss: [0.49778342, 0.3125]---fake_loss: [0.27605465, 0.78125]---GAN_LOSS: 15.169046401977539
# epoch 50: real_loss: [0.5272, 0.34375]---fake_loss: [0.2838347, 0.71875]---GAN_LOSS: 14.353365898132324
# epoch 51: real_loss: [0.51371294, 0.3125]---fake_loss: [0.28729475, 0.625]---GAN_LOSS: 16.13326644897461
# epoch 52: real_loss: [0.5270219, 0.375]---fake_loss: [0.26960546, 0.78125]---GAN_LOSS: 14.752032279968262
# epoch 53: real_loss: [0.50704116, 0.25]---fake_loss: [0.26178956, 0.8125]---GAN_LOSS: 13.970252990722656
# epoch 54: real_loss: [0.503492, 0.40625]---fake_loss: [0.29350835, 0.625]---GAN_LOSS: 15.163473129272461
# epoch 55: real_loss: [0.5263195, 0.28125]---fake_loss: [0.2746565, 0.78125]---GAN_LOSS: 14.876531600952148
# epoch 56: real_loss: [0.51503587, 0.25]---fake_loss: [0.28601205, 0.65625]---GAN_LOSS: 14.053533554077148
# epoch 57: real_loss: [0.49785635, 0.28125]---fake_loss: [0.2724468, 0.65625]---GAN_LOSS: 14.484321594238281
# epoch 58: real_loss: [0.4859477, 0.25]---fake_loss: [0.28113443, 0.78125]---GAN_LOSS: 14.724737167358398
# epoch 59: real_loss: [0.4929673, 0.21875]---fake_loss: [0.27991065, 0.78125]---GAN_LOSS: 15.430594444274902
# epoch 60: real_loss: [0.500577, 0.25]---fake_loss: [0.27650017, 0.8125]---GAN_LOSS: 13.959909439086914
# epoch 61: real_loss: [0.47775164, 0.1875]---fake_loss: [0.2825705, 0.65625]---GAN_LOSS: 15.886280059814453
# epoch 62: real_loss: [0.50164175, 0.34375]---fake_loss: [0.2765578, 0.8125]---GAN_LOSS: 15.297693252563477
# epoch 63: real_loss: [0.49591357, 0.28125]---fake_loss: [0.28934446, 0.75]---GAN_LOSS: 13.471097946166992
# epoch 64: real_loss: [0.5035901, 0.3125]---fake_loss: [0.29741663, 0.65625]---GAN_LOSS: 15.01268482208252
# epoch 65: real_loss: [0.48874697, 0.21875]---fake_loss: [0.26744893, 0.8125]---GAN_LOSS: 13.724595069885254
# epoch 66: real_loss: [0.4975828, 0.28125]---fake_loss: [0.28725547, 0.6875]---GAN_LOSS: 13.177462577819824
# epoch 67: real_loss: [0.4956, 0.25]---fake_loss: [0.28675747, 0.71875]---GAN_LOSS: 14.462491035461426
# epoch 68: real_loss: [0.49116206, 0.25]---fake_loss: [0.26202357, 0.8125]---GAN_LOSS: 15.842597961425781
# epoch 69: real_loss: [0.49439895, 0.21875]---fake_loss: [0.28568375, 0.75]---GAN_LOSS: 14.863590240478516
# epoch 70: real_loss: [0.5106285, 0.34375]---fake_loss: [0.28434792, 0.78125]---GAN_LOSS: 15.033811569213867
# epoch 71: real_loss: [0.50495577, 0.34375]---fake_loss: [0.27661926, 0.65625]---GAN_LOSS: 14.454482078552246
# epoch 72: real_loss: [0.4942562, 0.25]---fake_loss: [0.28164095, 0.71875]---GAN_LOSS: 15.374981880187988
# epoch 73: real_loss: [0.49537194, 0.34375]---fake_loss: [0.2799812, 0.84375]---GAN_LOSS: 13.463619232177734
# epoch 74: real_loss: [0.49995714, 0.34375]---fake_loss: [0.28138041, 0.78125]---GAN_LOSS: 14.467804908752441
# epoch 75: real_loss: [0.5054012, 0.40625]---fake_loss: [0.29322705, 0.75]---GAN_LOSS: 14.53889274597168
# epoch 76: real_loss: [0.47851133, 0.21875]---fake_loss: [0.27714643, 0.75]---GAN_LOSS: 14.413110733032227
# epoch 77: real_loss: [0.49075538, 0.25]---fake_loss: [0.2928681, 0.625]---GAN_LOSS: 14.198480606079102
# epoch 78: real_loss: [0.47973892, 0.25]---fake_loss: [0.28370243, 0.75]---GAN_LOSS: 14.10426139831543
# epoch 79: real_loss: [0.48272166, 0.3125]---fake_loss: [0.29044098, 0.625]---GAN_LOSS: 13.745861053466797
# epoch 80: real_loss: [0.4801567, 0.1875]---fake_loss: [0.27219206, 0.71875]---GAN_LOSS: 13.721843719482422
# epoch 81: real_loss: [0.49565807, 0.28125]---fake_loss: [0.28250128, 0.71875]---GAN_LOSS: 15.10628604888916
# epoch 82: real_loss: [0.46748027, 0.25]---fake_loss: [0.31377342, 0.59375]---GAN_LOSS: 13.05684757232666
# epoch 83: real_loss: [0.48622936, 0.21875]---fake_loss: [0.29106918, 0.71875]---GAN_LOSS: 13.412906646728516
# epoch 84: real_loss: [0.4889951, 0.28125]---fake_loss: [0.27711844, 0.6875]---GAN_LOSS: 13.325051307678223
# epoch 85: real_loss: [0.49556318, 0.28125]---fake_loss: [0.28982127, 0.71875]---GAN_LOSS: 14.5438871383667
# epoch 86: real_loss: [0.4821152, 0.25]---fake_loss: [0.27838933, 0.78125]---GAN_LOSS: 13.029742240905762
# epoch 87: real_loss: [0.47078192, 0.25]---fake_loss: [0.28922784, 0.71875]---GAN_LOSS: 14.110774040222168
# epoch 88: real_loss: [0.46955588, 0.3125]---fake_loss: [0.28039837, 0.75]---GAN_LOSS: 13.127318382263184
# epoch 89: real_loss: [0.4620554, 0.28125]---fake_loss: [0.2789988, 0.71875]---GAN_LOSS: 12.799356460571289
# epoch 90: real_loss: [0.4840232, 0.25]---fake_loss: [0.27675277, 0.78125]---GAN_LOSS: 12.885183334350586
# epoch 91: real_loss: [0.4836997, 0.25]---fake_loss: [0.27962983, 0.6875]---GAN_LOSS: 13.986021041870117
# epoch 92: real_loss: [0.477242, 0.25]---fake_loss: [0.290767, 0.625]---GAN_LOSS: 12.890912055969238
# epoch 93: real_loss: [0.46773952, 0.21875]---fake_loss: [0.2686112, 0.8125]---GAN_LOSS: 13.022074699401855
# epoch 94: real_loss: [0.48143342, 0.25]---fake_loss: [0.28116658, 0.75]---GAN_LOSS: 13.954887390136719
# epoch 95: real_loss: [0.49007514, 0.34375]---fake_loss: [0.27066016, 0.84375]---GAN_LOSS: 13.18080997467041
# epoch 96: real_loss: [0.46284968, 0.21875]---fake_loss: [0.27788067, 0.75]---GAN_LOSS: 14.53769302368164
# epoch 97: real_loss: [0.47007832, 0.28125]---fake_loss: [0.2840665, 0.6875]---GAN_LOSS: 12.670548439025879
# epoch 98: real_loss: [0.4856282, 0.25]---fake_loss: [0.27760166, 0.78125]---GAN_LOSS: 14.206503868103027
# epoch 99: real_loss: [0.46973976, 0.3125]---fake_loss: [0.28037828, 0.6875]---GAN_LOSS: 12.3582181930542
# epoch 100: real_loss: [0.4910951, 0.3125]---fake_loss: [0.2861103, 0.75]---GAN_LOSS: 12.355842590332031
# epoch 101: real_loss: [0.47237897, 0.34375]---fake_loss: [0.27293533, 0.84375]---GAN_LOSS: 12.580488204956055
# epoch 102: real_loss: [0.49226755, 0.375]---fake_loss: [0.28294978, 0.8125]---GAN_LOSS: 12.121073722839355
# epoch 103: real_loss: [0.47023153, 0.3125]---fake_loss: [0.2830937, 0.71875]---GAN_LOSS: 13.27496337890625
# epoch 104: real_loss: [0.48097062, 0.28125]---fake_loss: [0.28721333, 0.71875]---GAN_LOSS: 12.931012153625488
# epoch 105: real_loss: [0.45898008, 0.25]---fake_loss: [0.27702856, 0.71875]---GAN_LOSS: 14.375653266906738
# epoch 106: real_loss: [0.46606392, 0.15625]---fake_loss: [0.29208162, 0.625]---GAN_LOSS: 12.621969223022461
# epoch 107: real_loss: [0.46294987, 0.28125]---fake_loss: [0.27138448, 0.75]---GAN_LOSS: 14.93453598022461
# epoch 108: real_loss: [0.46231642, 0.25]---fake_loss: [0.28765437, 0.75]---GAN_LOSS: 13.973430633544922
# epoch 109: real_loss: [0.47573915, 0.28125]---fake_loss: [0.28030634, 0.71875]---GAN_LOSS: 12.648319244384766
# epoch 110: real_loss: [0.46761927, 0.25]---fake_loss: [0.2870834, 0.71875]---GAN_LOSS: 12.45217514038086
# epoch 111: real_loss: [0.46502188, 0.28125]---fake_loss: [0.2835256, 0.65625]---GAN_LOSS: 12.626655578613281
# epoch 112: real_loss: [0.45946914, 0.25]---fake_loss: [0.27536765, 0.71875]---GAN_LOSS: 13.2275972366333
# epoch 113: real_loss: [0.45590943, 0.15625]---fake_loss: [0.27519053, 0.6875]---GAN_LOSS: 12.716751098632812
# epoch 114: real_loss: [0.4656449, 0.3125]---fake_loss: [0.27952173, 0.71875]---GAN_LOSS: 14.378616333007812
# epoch 115: real_loss: [0.47369504, 0.1875]---fake_loss: [0.2773852, 0.75]---GAN_LOSS: 11.725462913513184
# epoch 116: real_loss: [0.47184154, 0.1875]---fake_loss: [0.2724986, 0.78125]---GAN_LOSS: 10.885671615600586
# epoch 117: real_loss: [0.4847642, 0.21875]---fake_loss: [0.2919482, 0.6875]---GAN_LOSS: 13.387229919433594
# epoch 118: real_loss: [0.47208306, 0.25]---fake_loss: [0.28630963, 0.71875]---GAN_LOSS: 13.64136028289795
# epoch 119: real_loss: [0.47085717, 0.25]---fake_loss: [0.2772354, 0.78125]---GAN_LOSS: 13.173439025878906
# epoch 120: real_loss: [0.46094152, 0.21875]---fake_loss: [0.29533696, 0.75]---GAN_LOSS: 11.835527420043945
# epoch 121: real_loss: [0.47314358, 0.28125]---fake_loss: [0.28743333, 0.6875]---GAN_LOSS: 11.417795181274414
# epoch 122: real_loss: [0.47874546, 0.3125]---fake_loss: [0.28908914, 0.8125]---GAN_LOSS: 13.022194862365723
# epoch 123: real_loss: [0.4545975, 0.3125]---fake_loss: [0.27434003, 0.8125]---GAN_LOSS: 12.402848243713379
# epoch 124: real_loss: [0.46728134, 0.1875]---fake_loss: [0.28416663, 0.8125]---GAN_LOSS: 11.458135604858398
# epoch 125: real_loss: [0.45878297, 0.21875]---fake_loss: [0.28039753, 0.6875]---GAN_LOSS: 11.568090438842773
# epoch 126: real_loss: [0.47746482, 0.28125]---fake_loss: [0.27087379, 0.8125]---GAN_LOSS: 12.342140197753906
# epoch 127: real_loss: [0.4555692, 0.3125]---fake_loss: [0.29125994, 0.6875]---GAN_LOSS: 13.186941146850586
# epoch 128: real_loss: [0.4804425, 0.3125]---fake_loss: [0.26998824, 0.75]---GAN_LOSS: 11.533567428588867
# epoch 129: real_loss: [0.4534768, 0.1875]---fake_loss: [0.28263026, 0.71875]---GAN_LOSS: 12.730045318603516
# epoch 130: real_loss: [0.45881575, 0.28125]---fake_loss: [0.28890455, 0.71875]---GAN_LOSS: 12.6024808883667
# epoch 131: real_loss: [0.45555314, 0.15625]---fake_loss: [0.29068667, 0.65625]---GAN_LOSS: 12.93524169921875
# epoch 132: real_loss: [0.47817874, 0.3125]---fake_loss: [0.28446943, 0.6875]---GAN_LOSS: 13.023069381713867
# epoch 133: real_loss: [0.4656365, 0.3125]---fake_loss: [0.26860434, 0.78125]---GAN_LOSS: 12.58194637298584
# epoch 134: real_loss: [0.4689352, 0.28125]---fake_loss: [0.29066417, 0.6875]---GAN_LOSS: 12.070852279663086
# epoch 135: real_loss: [0.46099693, 0.21875]---fake_loss: [0.29092622, 0.71875]---GAN_LOSS: 13.292797088623047
# epoch 136: real_loss: [0.45224994, 0.21875]---fake_loss: [0.283331, 0.75]---GAN_LOSS: 12.277792930603027
# epoch 137: real_loss: [0.47111616, 0.28125]---fake_loss: [0.2820052, 0.78125]---GAN_LOSS: 12.829122543334961
# epoch 138: real_loss: [0.44689202, 0.1875]---fake_loss: [0.29244143, 0.8125]---GAN_LOSS: 11.449128150939941
# epoch 139: real_loss: [0.46438932, 0.15625]---fake_loss: [0.2719475, 0.78125]---GAN_LOSS: 11.304425239562988
# epoch 140: real_loss: [0.46058843, 0.21875]---fake_loss: [0.29821455, 0.6875]---GAN_LOSS: 11.712406158447266
# epoch 141: real_loss: [0.45804232, 0.25]---fake_loss: [0.27902484, 0.8125]---GAN_LOSS: 11.884397506713867
# epoch 142: real_loss: [0.46051794, 0.21875]---fake_loss: [0.29096964, 0.75]---GAN_LOSS: 12.898070335388184
# epoch 143: real_loss: [0.46913266, 0.28125]---fake_loss: [0.28324786, 0.8125]---GAN_LOSS: 11.476134300231934
# epoch 144: real_loss: [0.45580697, 0.1875]---fake_loss: [0.29410374, 0.71875]---GAN_LOSS: 12.945711135864258
# epoch 145: real_loss: [0.4655164, 0.1875]---fake_loss: [0.29227102, 0.65625]---GAN_LOSS: 11.040619850158691
# epoch 146: real_loss: [0.4497683, 0.21875]---fake_loss: [0.29681498, 0.625]---GAN_LOSS: 12.337620735168457
# epoch 147: real_loss: [0.4551492, 0.3125]---fake_loss: [0.29598814, 0.65625]---GAN_LOSS: 12.086505889892578
# epoch 148: real_loss: [0.45032683, 0.25]---fake_loss: [0.2797696, 0.6875]---GAN_LOSS: 12.31872844696045
# epoch 149: real_loss: [0.45234835, 0.21875]---fake_loss: [0.287593, 0.6875]---GAN_LOSS: 12.505754470825195
# epoch 150: real_loss: [0.44711477, 0.15625]---fake_loss: [0.28600433, 0.75]---GAN_LOSS: 11.076257705688477
# epoch 151: real_loss: [0.4401048, 0.21875]---fake_loss: [0.28815547, 0.71875]---GAN_LOSS: 13.254898071289062
# epoch 152: real_loss: [0.46075317, 0.21875]---fake_loss: [0.2871065, 0.71875]---GAN_LOSS: 11.609728813171387
# epoch 153: real_loss: [0.44185138, 0.21875]---fake_loss: [0.29900634, 0.65625]---GAN_LOSS: 12.108481407165527
# epoch 154: real_loss: [0.46236876, 0.34375]---fake_loss: [0.27854937, 0.78125]---GAN_LOSS: 12.193622589111328
# epoch 155: real_loss: [0.44805965, 0.15625]---fake_loss: [0.28930452, 0.78125]---GAN_LOSS: 13.592180252075195
# epoch 156: real_loss: [0.45683876, 0.25]---fake_loss: [0.2894788, 0.625]---GAN_LOSS: 12.197749137878418
# epoch 157: real_loss: [0.45698905, 0.28125]---fake_loss: [0.2898491, 0.78125]---GAN_LOSS: 12.394973754882812
# epoch 158: real_loss: [0.4481334, 0.28125]---fake_loss: [0.2882739, 0.625]---GAN_LOSS: 11.580960273742676
# epoch 159: real_loss: [0.45752013, 0.25]---fake_loss: [0.28984058, 0.75]---GAN_LOSS: 11.059725761413574
# epoch 160: real_loss: [0.45083004, 0.25]---fake_loss: [0.28477, 0.6875]---GAN_LOSS: 11.750051498413086
# epoch 161: real_loss: [0.44235998, 0.25]---fake_loss: [0.28215942, 0.78125]---GAN_LOSS: 11.426700592041016
# epoch 162: real_loss: [0.4550038, 0.34375]---fake_loss: [0.29065993, 0.71875]---GAN_LOSS: 11.052440643310547
# epoch 163: real_loss: [0.44586056, 0.28125]---fake_loss: [0.28399777, 0.8125]---GAN_LOSS: 11.661128997802734
# epoch 164: real_loss: [0.45354605, 0.1875]---fake_loss: [0.29511905, 0.75]---GAN_LOSS: 11.456984519958496
# epoch 165: real_loss: [0.4327277, 0.28125]---fake_loss: [0.27949062, 0.84375]---GAN_LOSS: 11.140682220458984
# epoch 166: real_loss: [0.44589883, 0.21875]---fake_loss: [0.29289114, 0.84375]---GAN_LOSS: 11.728029251098633
# epoch 167: real_loss: [0.45689914, 0.25]---fake_loss: [0.2979958, 0.75]---GAN_LOSS: 11.341137886047363
# epoch 168: real_loss: [0.4509255, 0.375]---fake_loss: [0.28889728, 0.75]---GAN_LOSS: 10.28019905090332
# epoch 169: real_loss: [0.44801012, 0.1875]---fake_loss: [0.31327006, 0.75]---GAN_LOSS: 11.250368118286133
# epoch 170: real_loss: [0.43897521, 0.1875]---fake_loss: [0.28222895, 0.75]---GAN_LOSS: 10.91648006439209
# epoch 171: real_loss: [0.45284432, 0.28125]---fake_loss: [0.28457046, 0.78125]---GAN_LOSS: 11.197172164916992
# epoch 172: real_loss: [0.43459213, 0.25]---fake_loss: [0.28694695, 0.78125]---GAN_LOSS: 12.392319679260254
# epoch 173: real_loss: [0.440616, 0.15625]---fake_loss: [0.2855876, 0.78125]---GAN_LOSS: 11.845887184143066
# epoch 174: real_loss: [0.4402303, 0.3125]---fake_loss: [0.28762966, 0.75]---GAN_LOSS: 11.720815658569336
# epoch 175: real_loss: [0.4421369, 0.28125]---fake_loss: [0.3001157, 0.8125]---GAN_LOSS: 12.421843528747559
# epoch 176: real_loss: [0.4373947, 0.25]---fake_loss: [0.30245286, 0.6875]---GAN_LOSS: 10.09533405303955
# epoch 177: real_loss: [0.4372865, 0.375]---fake_loss: [0.2809105, 0.78125]---GAN_LOSS: 10.428230285644531
# epoch 178: real_loss: [0.4416587, 0.21875]---fake_loss: [0.29115555, 0.6875]---GAN_LOSS: 10.43286418914795
# epoch 179: real_loss: [0.4515379, 0.25]---fake_loss: [0.2886324, 0.75]---GAN_LOSS: 11.646329879760742
# epoch 180: real_loss: [0.4351133, 0.3125]---fake_loss: [0.29684016, 0.78125]---GAN_LOSS: 11.647382736206055
# epoch 181: real_loss: [0.44196668, 0.28125]---fake_loss: [0.29347324, 0.75]---GAN_LOSS: 10.492263793945312
# epoch 182: real_loss: [0.44529572, 0.375]---fake_loss: [0.29287785, 0.75]---GAN_LOSS: 10.673450469970703
# epoch 183: real_loss: [0.4459902, 0.34375]---fake_loss: [0.29628494, 0.65625]---GAN_LOSS: 11.193048477172852
# epoch 184: real_loss: [0.4401271, 0.21875]---fake_loss: [0.2913076, 0.75]---GAN_LOSS: 10.615344047546387
# epoch 185: real_loss: [0.43492725, 0.1875]---fake_loss: [0.30196458, 0.71875]---GAN_LOSS: 11.381495475769043
# epoch 186: real_loss: [0.44052145, 0.21875]---fake_loss: [0.29268306, 0.8125]---GAN_LOSS: 10.563360214233398
# epoch 187: real_loss: [0.4332564, 0.1875]---fake_loss: [0.28683865, 0.75]---GAN_LOSS: 11.381451606750488
# epoch 188: real_loss: [0.44135368, 0.28125]---fake_loss: [0.28882444, 0.71875]---GAN_LOSS: 11.734186172485352
# epoch 189: real_loss: [0.43793875, 0.25]---fake_loss: [0.29082346, 0.78125]---GAN_LOSS: 10.627034187316895
# epoch 190: real_loss: [0.43913567, 0.1875]---fake_loss: [0.30676544, 0.625]---GAN_LOSS: 10.605622291564941
# epoch 191: real_loss: [0.4427214, 0.1875]---fake_loss: [0.29430267, 0.71875]---GAN_LOSS: 10.069658279418945
# epoch 192: real_loss: [0.43751174, 0.28125]---fake_loss: [0.28622127, 0.75]---GAN_LOSS: 11.380870819091797
# epoch 193: real_loss: [0.4396359, 0.25]---fake_loss: [0.3015536, 0.6875]---GAN_LOSS: 10.545602798461914
# epoch 194: real_loss: [0.44601274, 0.25]---fake_loss: [0.30431277, 0.625]---GAN_LOSS: 10.010355949401855
# epoch 195: real_loss: [0.4334379, 0.3125]---fake_loss: [0.28715828, 0.75]---GAN_LOSS: 11.18963623046875
# epoch 196: real_loss: [0.44470322, 0.1875]---fake_loss: [0.2955452, 0.65625]---GAN_LOSS: 10.723186492919922
# epoch 197: real_loss: [0.43755105, 0.1875]---fake_loss: [0.2894254, 0.8125]---GAN_LOSS: 11.623099327087402
# epoch 198: real_loss: [0.4343348, 0.21875]---fake_loss: [0.29449224, 0.78125]---GAN_LOSS: 10.289953231811523
# epoch 199: real_loss: [0.4304948, 0.3125]---fake_loss: [0.3041613, 0.8125]---GAN_LOSS: 10.603007316589355
# epoch 200: real_loss: [0.43109816, 0.15625]---fake_loss: [0.3002848, 0.71875]---GAN_LOSS: 9.941068649291992
# epoch 201: real_loss: [0.44580668, 0.25]---fake_loss: [0.29152668, 0.75]---GAN_LOSS: 10.028998374938965
# epoch 202: real_loss: [0.43229944, 0.1875]---fake_loss: [0.29221153, 0.65625]---GAN_LOSS: 10.349112510681152
# epoch 203: real_loss: [0.43533856, 0.28125]---fake_loss: [0.29610974, 0.78125]---GAN_LOSS: 9.60174560546875
# epoch 204: real_loss: [0.42880023, 0.15625]---fake_loss: [0.2899957, 0.84375]---GAN_LOSS: 10.564116477966309
# epoch 205: real_loss: [0.42411843, 0.1875]---fake_loss: [0.30008274, 0.6875]---GAN_LOSS: 10.123106002807617
# epoch 206: real_loss: [0.4526701, 0.25]---fake_loss: [0.28432453, 0.8125]---GAN_LOSS: 10.850740432739258
# epoch 207: real_loss: [0.4291454, 0.1875]---fake_loss: [0.28850675, 0.6875]---GAN_LOSS: 10.393250465393066
# epoch 208: real_loss: [0.43191543, 0.21875]---fake_loss: [0.2902736, 0.8125]---GAN_LOSS: 10.401735305786133
# epoch 209: real_loss: [0.43522304, 0.3125]---fake_loss: [0.2993071, 0.75]---GAN_LOSS: 9.902259826660156
# epoch 210: real_loss: [0.43223602, 0.3125]---fake_loss: [0.2967224, 0.65625]---GAN_LOSS: 9.308073043823242
# epoch 211: real_loss: [0.43833065, 0.28125]---fake_loss: [0.30903172, 0.6875]---GAN_LOSS: 9.885859489440918
# epoch 212: real_loss: [0.43724716, 0.28125]---fake_loss: [0.2939751, 0.78125]---GAN_LOSS: 10.391087532043457
# epoch 213: real_loss: [0.4309916, 0.28125]---fake_loss: [0.29400954, 0.8125]---GAN_LOSS: 10.479687690734863
# epoch 214: real_loss: [0.44705075, 0.21875]---fake_loss: [0.3043133, 0.71875]---GAN_LOSS: 10.231261253356934
# epoch 215: real_loss: [0.44206423, 0.375]---fake_loss: [0.2966205, 0.71875]---GAN_LOSS: 12.161772727966309
# epoch 216: real_loss: [0.42632902, 0.3125]---fake_loss: [0.2914131, 0.78125]---GAN_LOSS: 10.074289321899414
# epoch 217: real_loss: [0.4235931, 0.25]---fake_loss: [0.2967593, 0.75]---GAN_LOSS: 10.317651748657227
# epoch 218: real_loss: [0.43067223, 0.1875]---fake_loss: [0.2955888, 0.71875]---GAN_LOSS: 10.159316062927246
# epoch 219: real_loss: [0.43164384, 0.21875]---fake_loss: [0.29617256, 0.8125]---GAN_LOSS: 11.57017707824707
# epoch 220: real_loss: [0.42476764, 0.28125]---fake_loss: [0.3048719, 0.75]---GAN_LOSS: 9.678179740905762
# epoch 221: real_loss: [0.4294824, 0.25]---fake_loss: [0.29516023, 0.78125]---GAN_LOSS: 10.53270435333252
# epoch 222: real_loss: [0.43621427, 0.28125]---fake_loss: [0.28923935, 0.78125]---GAN_LOSS: 9.264786720275879
# epoch 223: real_loss: [0.41386658, 0.28125]---fake_loss: [0.29915565, 0.75]---GAN_LOSS: 10.240205764770508
# epoch 224: real_loss: [0.42984074, 0.28125]---fake_loss: [0.2925727, 0.71875]---GAN_LOSS: 10.121567726135254
# epoch 225: real_loss: [0.4367622, 0.28125]---fake_loss: [0.308366, 0.59375]---GAN_LOSS: 9.202714920043945
# epoch 226: real_loss: [0.42713845, 0.3125]---fake_loss: [0.3005646, 0.71875]---GAN_LOSS: 8.904945373535156
# epoch 227: real_loss: [0.42539477, 0.1875]---fake_loss: [0.29709208, 0.75]---GAN_LOSS: 9.38867473602295
# epoch 228: real_loss: [0.42086303, 0.09375]---fake_loss: [0.30034032, 0.75]---GAN_LOSS: 9.959566116333008
# epoch 229: real_loss: [0.42820615, 0.34375]---fake_loss: [0.30236566, 0.65625]---GAN_LOSS: 9.912599563598633
# epoch 230: real_loss: [0.4214033, 0.28125]---fake_loss: [0.31236857, 0.6875]---GAN_LOSS: 10.64712142944336
# epoch 231: real_loss: [0.42889583, 0.28125]---fake_loss: [0.3034092, 0.6875]---GAN_LOSS: 10.296236038208008
# epoch 232: real_loss: [0.42671508, 0.25]---fake_loss: [0.3033185, 0.65625]---GAN_LOSS: 9.877392768859863
# epoch 233: real_loss: [0.42009145, 0.28125]---fake_loss: [0.29131076, 0.75]---GAN_LOSS: 9.387338638305664
# epoch 234: real_loss: [0.42699295, 0.1875]---fake_loss: [0.29654887, 0.71875]---GAN_LOSS: 9.674945831298828
# epoch 235: real_loss: [0.42763957, 0.125]---fake_loss: [0.2942497, 0.75]---GAN_LOSS: 8.703756332397461
# epoch 236: real_loss: [0.43728897, 0.3125]---fake_loss: [0.29533237, 0.8125]---GAN_LOSS: 9.880329132080078
# epoch 237: real_loss: [0.42596155, 0.28125]---fake_loss: [0.30701613, 0.625]---GAN_LOSS: 10.976757049560547
# epoch 238: real_loss: [0.43394104, 0.375]---fake_loss: [0.30792338, 0.71875]---GAN_LOSS: 9.69128131866455
# epoch 239: real_loss: [0.440799, 0.1875]---fake_loss: [0.29423404, 0.71875]---GAN_LOSS: 9.750060081481934
# epoch 240: real_loss: [0.42322212, 0.28125]---fake_loss: [0.3167467, 0.53125]---GAN_LOSS: 8.502378463745117
# epoch 241: real_loss: [0.42062432, 0.3125]---fake_loss: [0.29905957, 0.75]---GAN_LOSS: 9.481492042541504
# epoch 242: real_loss: [0.4236501, 0.21875]---fake_loss: [0.30194134, 0.65625]---GAN_LOSS: 10.231285095214844
# epoch 243: real_loss: [0.41289288, 0.21875]---fake_loss: [0.29756594, 0.75]---GAN_LOSS: 9.799650192260742
# epoch 244: real_loss: [0.41021532, 0.28125]---fake_loss: [0.29940873, 0.78125]---GAN_LOSS: 9.573091506958008
# epoch 245: real_loss: [0.42216152, 0.21875]---fake_loss: [0.29727244, 0.6875]---GAN_LOSS: 9.074674606323242
# epoch 246: real_loss: [0.4197188, 0.28125]---fake_loss: [0.30128986, 0.71875]---GAN_LOSS: 8.445323944091797
# epoch 247: real_loss: [0.4109489, 0.15625]---fake_loss: [0.29670137, 0.75]---GAN_LOSS: 9.800440788269043
# epoch 248: real_loss: [0.4201453, 0.25]---fake_loss: [0.30469537, 0.75]---GAN_LOSS: 8.716233253479004
# epoch 249: real_loss: [0.42157373, 0.3125]---fake_loss: [0.30137056, 0.71875]---GAN_LOSS: 8.895195007324219
# epoch 250: real_loss: [0.41644758, 0.34375]---fake_loss: [0.3105698, 0.75]---GAN_LOSS: 9.595271110534668
# epoch 251: real_loss: [0.42151374, 0.3125]---fake_loss: [0.29831043, 0.6875]---GAN_LOSS: 9.669576644897461
# epoch 252: real_loss: [0.41868466, 0.21875]---fake_loss: [0.29522347, 0.84375]---GAN_LOSS: 9.564624786376953
# epoch 253: real_loss: [0.42164052, 0.3125]---fake_loss: [0.3043397, 0.625]---GAN_LOSS: 9.237539291381836
# epoch 254: real_loss: [0.42716187, 0.21875]---fake_loss: [0.29244363, 0.71875]---GAN_LOSS: 9.68008804321289
# epoch 255: real_loss: [0.41782093, 0.21875]---fake_loss: [0.31362543, 0.6875]---GAN_LOSS: 9.161994934082031
# epoch 256: real_loss: [0.3983217, 0.28125]---fake_loss: [0.30395854, 0.71875]---GAN_LOSS: 8.68120002746582
# epoch 257: real_loss: [0.42564303, 0.40625]---fake_loss: [0.3061208, 0.65625]---GAN_LOSS: 9.980398178100586
# epoch 258: real_loss: [0.41644174, 0.25]---fake_loss: [0.30531088, 0.71875]---GAN_LOSS: 9.60269832611084
# epoch 259: real_loss: [0.41538003, 0.3125]---fake_loss: [0.30940914, 0.71875]---GAN_LOSS: 9.521075248718262
# epoch 260: real_loss: [0.4240445, 0.1875]---fake_loss: [0.30294165, 0.78125]---GAN_LOSS: 9.15802001953125
# epoch 261: real_loss: [0.42722213, 0.1875]---fake_loss: [0.30099297, 0.75]---GAN_LOSS: 8.311563491821289
# epoch 262: real_loss: [0.41550928, 0.34375]---fake_loss: [0.30153668, 0.75]---GAN_LOSS: 8.865179061889648
# epoch 263: real_loss: [0.42749542, 0.25]---fake_loss: [0.3160936, 0.6875]---GAN_LOSS: 9.516169548034668
# epoch 264: real_loss: [0.40801775, 0.1875]---fake_loss: [0.30597484, 0.78125]---GAN_LOSS: 9.716133117675781
# epoch 265: real_loss: [0.41445863, 0.25]---fake_loss: [0.29929456, 0.78125]---GAN_LOSS: 8.997702598571777
# epoch 266: real_loss: [0.413063, 0.15625]---fake_loss: [0.30665067, 0.6875]---GAN_LOSS: 10.020853042602539
# epoch 267: real_loss: [0.41850063, 0.3125]---fake_loss: [0.3050781, 0.6875]---GAN_LOSS: 9.376327514648438
# epoch 268: real_loss: [0.40677202, 0.375]---fake_loss: [0.29682857, 0.84375]---GAN_LOSS: 9.373836517333984
# epoch 269: real_loss: [0.4166602, 0.28125]---fake_loss: [0.30575347, 0.6875]---GAN_LOSS: 9.595643043518066
# epoch 270: real_loss: [0.4192628, 0.25]---fake_loss: [0.30027524, 0.65625]---GAN_LOSS: 9.224651336669922
# epoch 271: real_loss: [0.4132452, 0.25]---fake_loss: [0.29713768, 0.8125]---GAN_LOSS: 9.462348937988281
# epoch 272: real_loss: [0.4214474, 0.25]---fake_loss: [0.31982628, 0.71875]---GAN_LOSS: 9.341919898986816
# epoch 273: real_loss: [0.42009836, 0.21875]---fake_loss: [0.31069306, 0.71875]---GAN_LOSS: 8.88135051727295
# epoch 274: real_loss: [0.40722793, 0.3125]---fake_loss: [0.30438805, 0.78125]---GAN_LOSS: 8.385933876037598
# epoch 275: real_loss: [0.4216449, 0.34375]---fake_loss: [0.30356058, 0.75]---GAN_LOSS: 8.323549270629883
# epoch 276: real_loss: [0.41448554, 0.25]---fake_loss: [0.3020463, 0.65625]---GAN_LOSS: 8.625115394592285
# epoch 277: real_loss: [0.41488016, 0.25]---fake_loss: [0.3112224, 0.6875]---GAN_LOSS: 8.99436092376709
# epoch 278: real_loss: [0.4151808, 0.28125]---fake_loss: [0.3017233, 0.65625]---GAN_LOSS: 9.398669242858887
# epoch 279: real_loss: [0.41109917, 0.34375]---fake_loss: [0.31899828, 0.59375]---GAN_LOSS: 8.673277854919434
# epoch 280: real_loss: [0.40238062, 0.25]---fake_loss: [0.30509436, 0.75]---GAN_LOSS: 9.046815872192383
# epoch 281: real_loss: [0.40621954, 0.25]---fake_loss: [0.3119809, 0.65625]---GAN_LOSS: 8.247030258178711
# epoch 282: real_loss: [0.41502905, 0.28125]---fake_loss: [0.3035892, 0.75]---GAN_LOSS: 8.827327728271484
# epoch 283: real_loss: [0.40975314, 0.4375]---fake_loss: [0.30057362, 0.78125]---GAN_LOSS: 9.599609375
# epoch 284: real_loss: [0.40341198, 0.34375]---fake_loss: [0.30574086, 0.71875]---GAN_LOSS: 8.836094856262207
# epoch 285: real_loss: [0.41311955, 0.3125]---fake_loss: [0.31807035, 0.71875]---GAN_LOSS: 8.69858169555664
# epoch 286: real_loss: [0.40985227, 0.25]---fake_loss: [0.31726408, 0.65625]---GAN_LOSS: 8.302638053894043
# epoch 287: real_loss: [0.40991724, 0.3125]---fake_loss: [0.30715585, 0.75]---GAN_LOSS: 8.434591293334961
# epoch 288: real_loss: [0.40823865, 0.34375]---fake_loss: [0.3133497, 0.6875]---GAN_LOSS: 9.424497604370117
# epoch 289: real_loss: [0.408512, 0.25]---fake_loss: [0.30579764, 0.78125]---GAN_LOSS: 8.480812072753906
# epoch 290: real_loss: [0.40685767, 0.3125]---fake_loss: [0.3051563, 0.6875]---GAN_LOSS: 8.682905197143555
# epoch 291: real_loss: [0.4024464, 0.3125]---fake_loss: [0.3155965, 0.6875]---GAN_LOSS: 8.210420608520508
# epoch 292: real_loss: [0.40688464, 0.3125]---fake_loss: [0.30443853, 0.65625]---GAN_LOSS: 8.663801193237305
# epoch 293: real_loss: [0.406374, 0.25]---fake_loss: [0.3100833, 0.65625]---GAN_LOSS: 9.484541893005371
# epoch 294: real_loss: [0.40424725, 0.25]---fake_loss: [0.30847508, 0.75]---GAN_LOSS: 9.275707244873047
# epoch 295: real_loss: [0.40578175, 0.3125]---fake_loss: [0.29860038, 0.71875]---GAN_LOSS: 8.099299430847168
# epoch 296: real_loss: [0.41869366, 0.21875]---fake_loss: [0.3128655, 0.71875]---GAN_LOSS: 8.35881233215332
# epoch 297: real_loss: [0.4124939, 0.28125]---fake_loss: [0.30614388, 0.78125]---GAN_LOSS: 8.229984283447266
# epoch 298: real_loss: [0.3912472, 0.28125]---fake_loss: [0.30353832, 0.75]---GAN_LOSS: 7.822938919067383
# epoch 299: real_loss: [0.39894813, 0.25]---fake_loss: [0.30913484, 0.625]---GAN_LOSS: 8.683701515197754
# epoch 300: real_loss: [0.4042541, 0.3125]---fake_loss: [0.30384004, 0.78125]---GAN_LOSS: 8.465376853942871
# epoch 301: real_loss: [0.41493785, 0.3125]---fake_loss: [0.30631274, 0.65625]---GAN_LOSS: 7.888971328735352
# epoch 302: real_loss: [0.40407088, 0.40625]---fake_loss: [0.30942112, 0.75]---GAN_LOSS: 8.838638305664062
# epoch 303: real_loss: [0.4053565, 0.34375]---fake_loss: [0.30499002, 0.625]---GAN_LOSS: 7.519168853759766
# epoch 304: real_loss: [0.41087526, 0.3125]---fake_loss: [0.30411884, 0.71875]---GAN_LOSS: 8.542914390563965
# epoch 305: real_loss: [0.42335874, 0.25]---fake_loss: [0.31183785, 0.625]---GAN_LOSS: 8.636273384094238
# epoch 306: real_loss: [0.4122721, 0.3125]---fake_loss: [0.31832463, 0.65625]---GAN_LOSS: 9.116584777832031
# epoch 307: real_loss: [0.40905616, 0.375]---fake_loss: [0.30660027, 0.71875]---GAN_LOSS: 8.785684585571289
# epoch 308: real_loss: [0.41286308, 0.34375]---fake_loss: [0.31096002, 0.65625]---GAN_LOSS: 9.09972095489502
# epoch 309: real_loss: [0.42030317, 0.3125]---fake_loss: [0.31157267, 0.6875]---GAN_LOSS: 8.496072769165039
# epoch 310: real_loss: [0.39553773, 0.34375]---fake_loss: [0.3131301, 0.71875]---GAN_LOSS: 7.807491302490234
# epoch 311: real_loss: [0.41595024, 0.28125]---fake_loss: [0.30741298, 0.90625]---GAN_LOSS: 8.725629806518555
# epoch 312: real_loss: [0.3906358, 0.3125]---fake_loss: [0.31286192, 0.6875]---GAN_LOSS: 7.762462615966797
# epoch 313: real_loss: [0.39500833, 0.53125]---fake_loss: [0.3051752, 0.71875]---GAN_LOSS: 8.122002601623535
# epoch 314: real_loss: [0.4145794, 0.28125]---fake_loss: [0.31175625, 0.65625]---GAN_LOSS: 9.16107177734375
# epoch 315: real_loss: [0.40127897, 0.28125]---fake_loss: [0.3128364, 0.625]---GAN_LOSS: 8.105981826782227
# epoch 316: real_loss: [0.40537348, 0.3125]---fake_loss: [0.3092758, 0.71875]---GAN_LOSS: 8.991277694702148
# epoch 317: real_loss: [0.40533718, 0.25]---fake_loss: [0.30689555, 0.625]---GAN_LOSS: 8.608246803283691
# epoch 318: real_loss: [0.4093548, 0.25]---fake_loss: [0.3053467, 0.71875]---GAN_LOSS: 7.735265731811523
# epoch 319: real_loss: [0.4044665, 0.28125]---fake_loss: [0.31032616, 0.8125]---GAN_LOSS: 8.55044174194336
# epoch 320: real_loss: [0.39963424, 0.25]---fake_loss: [0.3067666, 0.71875]---GAN_LOSS: 8.674474716186523
# epoch 321: real_loss: [0.40752494, 0.21875]---fake_loss: [0.3234362, 0.71875]---GAN_LOSS: 8.206594467163086
# epoch 322: real_loss: [0.40263295, 0.3125]---fake_loss: [0.3096133, 0.75]---GAN_LOSS: 7.864018440246582
# epoch 323: real_loss: [0.39673817, 0.375]---fake_loss: [0.32416296, 0.625]---GAN_LOSS: 8.342707633972168
# epoch 324: real_loss: [0.4019786, 0.28125]---fake_loss: [0.32215273, 0.71875]---GAN_LOSS: 8.28707218170166
# epoch 325: real_loss: [0.3947065, 0.3125]---fake_loss: [0.31652415, 0.6875]---GAN_LOSS: 8.30897331237793
# epoch 326: real_loss: [0.40345728, 0.21875]---fake_loss: [0.31446636, 0.625]---GAN_LOSS: 8.0549898147583
# epoch 327: real_loss: [0.4073341, 0.25]---fake_loss: [0.30503714, 0.65625]---GAN_LOSS: 7.856978893280029
# epoch 328: real_loss: [0.39779413, 0.1875]---fake_loss: [0.30901212, 0.75]---GAN_LOSS: 8.324904441833496
# epoch 329: real_loss: [0.3965181, 0.28125]---fake_loss: [0.30931908, 0.6875]---GAN_LOSS: 8.27520751953125
# epoch 330: real_loss: [0.40526098, 0.21875]---fake_loss: [0.30933565, 0.625]---GAN_LOSS: 8.603202819824219
# epoch 331: real_loss: [0.40363747, 0.34375]---fake_loss: [0.30996126, 0.75]---GAN_LOSS: 8.065998077392578
# epoch 332: real_loss: [0.4024376, 0.21875]---fake_loss: [0.31906682, 0.75]---GAN_LOSS: 8.050561904907227
# epoch 333: real_loss: [0.40299183, 0.28125]---fake_loss: [0.3151788, 0.71875]---GAN_LOSS: 8.307587623596191
# epoch 334: real_loss: [0.40537465, 0.40625]---fake_loss: [0.2992563, 0.75]---GAN_LOSS: 7.520125389099121
# epoch 335: real_loss: [0.41126817, 0.25]---fake_loss: [0.323607, 0.625]---GAN_LOSS: 8.181654930114746
# epoch 336: real_loss: [0.40416074, 0.3125]---fake_loss: [0.31127465, 0.6875]---GAN_LOSS: 8.29210090637207
# epoch 337: real_loss: [0.40834552, 0.28125]---fake_loss: [0.31351215, 0.71875]---GAN_LOSS: 8.878335952758789
# epoch 338: real_loss: [0.4050147, 0.34375]---fake_loss: [0.31488073, 0.6875]---GAN_LOSS: 8.124780654907227
# epoch 339: real_loss: [0.39203137, 0.34375]---fake_loss: [0.31873798, 0.65625]---GAN_LOSS: 8.828425407409668
# epoch 340: real_loss: [0.40873057, 0.28125]---fake_loss: [0.3140627, 0.6875]---GAN_LOSS: 7.985519886016846
# epoch 341: real_loss: [0.39982694, 0.1875]---fake_loss: [0.3079521, 0.75]---GAN_LOSS: 7.495655536651611
# epoch 342: real_loss: [0.3970706, 0.15625]---fake_loss: [0.30470523, 0.8125]---GAN_LOSS: 7.428104877471924
# epoch 343: real_loss: [0.395871, 0.375]---fake_loss: [0.31075048, 0.6875]---GAN_LOSS: 8.125786781311035
# epoch 344: real_loss: [0.39756545, 0.21875]---fake_loss: [0.30528104, 0.6875]---GAN_LOSS: 8.054341316223145
# epoch 345: real_loss: [0.40733993, 0.1875]---fake_loss: [0.31334677, 0.71875]---GAN_LOSS: 7.162199020385742
# epoch 346: real_loss: [0.40481305, 0.34375]---fake_loss: [0.3017126, 0.75]---GAN_LOSS: 8.303033828735352
# epoch 347: real_loss: [0.39416498, 0.4375]---fake_loss: [0.3047238, 0.71875]---GAN_LOSS: 7.907096862792969
# epoch 348: real_loss: [0.39223486, 0.21875]---fake_loss: [0.30736738, 0.8125]---GAN_LOSS: 7.868260383605957
# epoch 349: real_loss: [0.3974629, 0.34375]---fake_loss: [0.31767017, 0.6875]---GAN_LOSS: 7.6804704666137695
# epoch 350: real_loss: [0.41249081, 0.25]---fake_loss: [0.3092608, 0.65625]---GAN_LOSS: 8.239940643310547
# epoch 351: real_loss: [0.40388867, 0.28125]---fake_loss: [0.31223544, 0.71875]---GAN_LOSS: 8.420454025268555
# epoch 352: real_loss: [0.39375865, 0.3125]---fake_loss: [0.31157464, 0.75]---GAN_LOSS: 7.698256969451904
# epoch 353: real_loss: [0.3940358, 0.28125]---fake_loss: [0.31842023, 0.71875]---GAN_LOSS: 7.496671199798584
# epoch 354: real_loss: [0.39517826, 0.34375]---fake_loss: [0.30528554, 0.8125]---GAN_LOSS: 7.1875433921813965
# epoch 355: real_loss: [0.3983549, 0.34375]---fake_loss: [0.307496, 0.78125]---GAN_LOSS: 7.800034523010254
# epoch 356: real_loss: [0.40122557, 0.28125]---fake_loss: [0.3069907, 0.75]---GAN_LOSS: 8.218718528747559
# epoch 357: real_loss: [0.39636415, 0.21875]---fake_loss: [0.30507636, 0.71875]---GAN_LOSS: 7.443310737609863
# epoch 358: real_loss: [0.3959388, 0.25]---fake_loss: [0.31362742, 0.71875]---GAN_LOSS: 8.291572570800781
# epoch 359: real_loss: [0.39957947, 0.375]---fake_loss: [0.3096313, 0.65625]---GAN_LOSS: 7.492523193359375
# epoch 360: real_loss: [0.3886055, 0.28125]---fake_loss: [0.31959206, 0.78125]---GAN_LOSS: 7.926713466644287
# epoch 361: real_loss: [0.39366767, 0.34375]---fake_loss: [0.31073993, 0.75]---GAN_LOSS: 7.824070453643799
# epoch 362: real_loss: [0.3876381, 0.25]---fake_loss: [0.31097156, 0.71875]---GAN_LOSS: 8.221384048461914
# epoch 363: real_loss: [0.38730645, 0.21875]---fake_loss: [0.3167033, 0.65625]---GAN_LOSS: 7.301980972290039
# epoch 364: real_loss: [0.3938502, 0.3125]---fake_loss: [0.30538398, 0.6875]---GAN_LOSS: 8.273442268371582
# epoch 365: real_loss: [0.39497942, 0.34375]---fake_loss: [0.31895083, 0.625]---GAN_LOSS: 8.483587265014648
# epoch 366: real_loss: [0.40051496, 0.34375]---fake_loss: [0.30458984, 0.78125]---GAN_LOSS: 7.493426322937012
# epoch 367: real_loss: [0.40184385, 0.28125]---fake_loss: [0.31168443, 0.71875]---GAN_LOSS: 7.801515579223633
# epoch 368: real_loss: [0.38297325, 0.4375]---fake_loss: [0.32261378, 0.65625]---GAN_LOSS: 8.588065147399902
# epoch 369: real_loss: [0.40065476, 0.28125]---fake_loss: [0.3068818, 0.71875]---GAN_LOSS: 8.161169052124023
# epoch 370: real_loss: [0.3963262, 0.28125]---fake_loss: [0.32432628, 0.65625]---GAN_LOSS: 7.894863605499268
# epoch 371: real_loss: [0.4033007, 0.40625]---fake_loss: [0.31738412, 0.625]---GAN_LOSS: 7.243030071258545
# epoch 372: real_loss: [0.3870417, 0.34375]---fake_loss: [0.31786728, 0.71875]---GAN_LOSS: 7.766069412231445
# epoch 373: real_loss: [0.39939404, 0.40625]---fake_loss: [0.31271416, 0.71875]---GAN_LOSS: 7.916390419006348
# epoch 374: real_loss: [0.39772773, 0.34375]---fake_loss: [0.31108585, 0.6875]---GAN_LOSS: 7.705256938934326
# epoch 375: real_loss: [0.38571453, 0.28125]---fake_loss: [0.31554258, 0.65625]---GAN_LOSS: 7.884521007537842
# epoch 376: real_loss: [0.39250445, 0.375]---fake_loss: [0.31828627, 0.59375]---GAN_LOSS: 7.536405563354492
# epoch 377: real_loss: [0.39751792, 0.34375]---fake_loss: [0.30947614, 0.71875]---GAN_LOSS: 8.059552192687988
# epoch 378: real_loss: [0.39518282, 0.25]---fake_loss: [0.31776893, 0.65625]---GAN_LOSS: 7.617654323577881
# epoch 379: real_loss: [0.39833575, 0.1875]---fake_loss: [0.31074092, 0.6875]---GAN_LOSS: 7.455455780029297
# epoch 380: real_loss: [0.40195695, 0.34375]---fake_loss: [0.31600142, 0.65625]---GAN_LOSS: 7.916774749755859
# epoch 381: real_loss: [0.41535005, 0.3125]---fake_loss: [0.31749126, 0.5625]---GAN_LOSS: 7.409511089324951
# epoch 382: real_loss: [0.39509547, 0.21875]---fake_loss: [0.30988204, 0.78125]---GAN_LOSS: 7.185175895690918
# epoch 383: real_loss: [0.39005184, 0.3125]---fake_loss: [0.319843, 0.65625]---GAN_LOSS: 7.45062255859375
# epoch 384: real_loss: [0.39568636, 0.25]---fake_loss: [0.3133734, 0.71875]---GAN_LOSS: 7.633929252624512
# epoch 385: real_loss: [0.39255354, 0.3125]---fake_loss: [0.31354284, 0.71875]---GAN_LOSS: 7.280091762542725
# epoch 386: real_loss: [0.39625615, 0.28125]---fake_loss: [0.31264156, 0.6875]---GAN_LOSS: 7.811177730560303
# epoch 387: real_loss: [0.39352778, 0.3125]---fake_loss: [0.31492603, 0.6875]---GAN_LOSS: 7.0396199226379395
# epoch 388: real_loss: [0.3921592, 0.4375]---fake_loss: [0.3148088, 0.625]---GAN_LOSS: 7.194269180297852
# epoch 389: real_loss: [0.3980332, 0.28125]---fake_loss: [0.3234228, 0.6875]---GAN_LOSS: 7.441348075866699
# epoch 390: real_loss: [0.38805497, 0.34375]---fake_loss: [0.3243641, 0.6875]---GAN_LOSS: 7.75238561630249
# epoch 391: real_loss: [0.39659917, 0.3125]---fake_loss: [0.3234806, 0.625]---GAN_LOSS: 7.871657371520996
# epoch 392: real_loss: [0.39009076, 0.25]---fake_loss: [0.32006204, 0.75]---GAN_LOSS: 7.307056903839111
# epoch 393: real_loss: [0.3839771, 0.375]---fake_loss: [0.31410345, 0.65625]---GAN_LOSS: 7.786153793334961
# epoch 394: real_loss: [0.39497352, 0.3125]---fake_loss: [0.31677216, 0.65625]---GAN_LOSS: 7.212299346923828
# epoch 395: real_loss: [0.3865795, 0.34375]---fake_loss: [0.32140228, 0.6875]---GAN_LOSS: 7.166395664215088
# epoch 396: real_loss: [0.39291304, 0.5]---fake_loss: [0.3211527, 0.6875]---GAN_LOSS: 6.961752891540527
# epoch 397: real_loss: [0.3920523, 0.375]---fake_loss: [0.31912932, 0.71875]---GAN_LOSS: 6.895571708679199
# epoch 398: real_loss: [0.3912931, 0.34375]---fake_loss: [0.31532508, 0.6875]---GAN_LOSS: 7.2151689529418945
# epoch 399: real_loss: [0.39525348, 0.3125]---fake_loss: [0.31602025, 0.71875]---GAN_LOSS: 7.477214813232422
# epoch 400: real_loss: [0.3862223, 0.3125]---fake_loss: [0.32677805, 0.59375]---GAN_LOSS: 7.438525199890137
# epoch 401: real_loss: [0.38442117, 0.375]---fake_loss: [0.3267287, 0.65625]---GAN_LOSS: 7.087960720062256
# epoch 402: real_loss: [0.40088755, 0.3125]---fake_loss: [0.32175803, 0.6875]---GAN_LOSS: 6.6725945472717285
# epoch 403: real_loss: [0.3822509, 0.375]---fake_loss: [0.3208202, 0.625]---GAN_LOSS: 7.122570991516113
# epoch 404: real_loss: [0.39415118, 0.40625]---fake_loss: [0.32577646, 0.5625]---GAN_LOSS: 7.5316081047058105
# epoch 405: real_loss: [0.39534372, 0.34375]---fake_loss: [0.31881273, 0.625]---GAN_LOSS: 7.471316337585449
# epoch 406: real_loss: [0.39936888, 0.34375]---fake_loss: [0.32686377, 0.6875]---GAN_LOSS: 8.314809799194336
# epoch 407: real_loss: [0.38954765, 0.40625]---fake_loss: [0.32349735, 0.71875]---GAN_LOSS: 7.815474510192871
# epoch 408: real_loss: [0.38888788, 0.34375]---fake_loss: [0.31803662, 0.5625]---GAN_LOSS: 7.6791300773620605
# epoch 409: real_loss: [0.39226007, 0.25]---fake_loss: [0.31351885, 0.65625]---GAN_LOSS: 7.649689197540283
# epoch 410: real_loss: [0.3857805, 0.375]---fake_loss: [0.31925976, 0.59375]---GAN_LOSS: 6.598775863647461
# epoch 411: real_loss: [0.3932865, 0.40625]---fake_loss: [0.31760013, 0.71875]---GAN_LOSS: 6.759143352508545
# epoch 412: real_loss: [0.39283848, 0.3125]---fake_loss: [0.31956553, 0.75]---GAN_LOSS: 7.186067581176758
# epoch 413: real_loss: [0.38150334, 0.375]---fake_loss: [0.30632594, 0.8125]---GAN_LOSS: 7.07820463180542
# epoch 414: real_loss: [0.3898517, 0.40625]---fake_loss: [0.31560522, 0.6875]---GAN_LOSS: 7.807263374328613
# epoch 415: real_loss: [0.3938807, 0.375]---fake_loss: [0.33227652, 0.71875]---GAN_LOSS: 6.739820957183838
# epoch 416: real_loss: [0.39124408, 0.34375]---fake_loss: [0.31941926, 0.6875]---GAN_LOSS: 7.013996601104736
# epoch 417: real_loss: [0.38438746, 0.28125]---fake_loss: [0.31482357, 0.6875]---GAN_LOSS: 6.825788974761963
# epoch 418: real_loss: [0.3900476, 0.28125]---fake_loss: [0.309547, 0.78125]---GAN_LOSS: 6.914971351623535
# epoch 419: real_loss: [0.38164872, 0.34375]---fake_loss: [0.31736445, 0.625]---GAN_LOSS: 7.315514087677002
# epoch 420: real_loss: [0.39268333, 0.3125]---fake_loss: [0.31767845, 0.6875]---GAN_LOSS: 6.825103282928467
# epoch 421: real_loss: [0.3884418, 0.28125]---fake_loss: [0.3206561, 0.65625]---GAN_LOSS: 6.677644729614258
# epoch 422: real_loss: [0.3835542, 0.40625]---fake_loss: [0.31242406, 0.65625]---GAN_LOSS: 7.650251865386963
# epoch 423: real_loss: [0.3941123, 0.3125]---fake_loss: [0.32555598, 0.625]---GAN_LOSS: 7.192533016204834
# epoch 424: real_loss: [0.39177117, 0.34375]---fake_loss: [0.31840277, 0.6875]---GAN_LOSS: 6.432167053222656
# epoch 425: real_loss: [0.38228577, 0.40625]---fake_loss: [0.32494068, 0.53125]---GAN_LOSS: 7.177727222442627
# epoch 426: real_loss: [0.38705286, 0.28125]---fake_loss: [0.32935405, 0.5625]---GAN_LOSS: 7.6549906730651855
# epoch 427: real_loss: [0.3909927, 0.34375]---fake_loss: [0.32306832, 0.625]---GAN_LOSS: 6.405568599700928
# epoch 428: real_loss: [0.3969133, 0.28125]---fake_loss: [0.33315983, 0.625]---GAN_LOSS: 7.75229549407959
# epoch 429: real_loss: [0.39086384, 0.375]---fake_loss: [0.323507, 0.53125]---GAN_LOSS: 8.164855003356934
# epoch 430: real_loss: [0.3973021, 0.3125]---fake_loss: [0.32471925, 0.6875]---GAN_LOSS: 6.941465377807617
# epoch 431: real_loss: [0.39383882, 0.40625]---fake_loss: [0.3236487, 0.625]---GAN_LOSS: 6.978974342346191
# epoch 432: real_loss: [0.38930556, 0.375]---fake_loss: [0.33054972, 0.625]---GAN_LOSS: 7.127346038818359
# epoch 433: real_loss: [0.37561923, 0.34375]---fake_loss: [0.32036304, 0.625]---GAN_LOSS: 6.683690547943115
# epoch 434: real_loss: [0.3911178, 0.34375]---fake_loss: [0.31644323, 0.75]---GAN_LOSS: 7.662247180938721
# epoch 435: real_loss: [0.38619775, 0.34375]---fake_loss: [0.31005442, 0.625]---GAN_LOSS: 6.638156890869141
# epoch 436: real_loss: [0.38870853, 0.3125]---fake_loss: [0.33014718, 0.75]---GAN_LOSS: 7.732302665710449
# epoch 437: real_loss: [0.38396472, 0.40625]---fake_loss: [0.32269463, 0.65625]---GAN_LOSS: 6.966655731201172
# epoch 438: real_loss: [0.3844162, 0.40625]---fake_loss: [0.32193026, 0.625]---GAN_LOSS: 6.788130760192871
# epoch 439: real_loss: [0.37796438, 0.40625]---fake_loss: [0.32665026, 0.625]---GAN_LOSS: 6.542077541351318
# epoch 440: real_loss: [0.3680185, 0.34375]---fake_loss: [0.32705814, 0.65625]---GAN_LOSS: 6.802802085876465
# epoch 441: real_loss: [0.39044434, 0.28125]---fake_loss: [0.32192653, 0.71875]---GAN_LOSS: 6.980168342590332
# epoch 442: real_loss: [0.38375235, 0.25]---fake_loss: [0.31497633, 0.8125]---GAN_LOSS: 6.649660110473633
# epoch 443: real_loss: [0.39542246, 0.3125]---fake_loss: [0.33142096, 0.5625]---GAN_LOSS: 6.595002174377441
# epoch 444: real_loss: [0.39048588, 0.1875]---fake_loss: [0.32559633, 0.625]---GAN_LOSS: 6.952473163604736
# epoch 445: real_loss: [0.37759432, 0.375]---fake_loss: [0.32218274, 0.59375]---GAN_LOSS: 7.252067565917969
# ...
# epoch 1729: real_loss: [0.36142328, 0.375]---fake_loss: [0.3413429, 0.59375]---GAN_LOSS: 2.8533997535705566
# epoch 1730: real_loss: [0.34692985, 0.46875]---fake_loss: [0.34427875, 0.53125]---GAN_LOSS: 2.8266592025756836
# epoch 1731: real_loss: [0.36403024, 0.40625]---fake_loss: [0.33504698, 0.59375]---GAN_LOSS: 2.3754169940948486
# epoch 1732: real_loss: [0.34004736, 0.65625]---fake_loss: [0.33840498, 0.59375]---GAN_LOSS: 2.678601026535034
# epoch 1733: real_loss: [0.35592872, 0.375]---fake_loss: [0.34503335, 0.5625]---GAN_LOSS: 2.8835978507995605
# epoch 1734: real_loss: [0.36965597, 0.53125]---fake_loss: [0.33528233, 0.59375]---GAN_LOSS: 2.816110610961914
# epoch 1735: real_loss: [0.34323275, 0.6875]---fake_loss: [0.33901283, 0.53125]---GAN_LOSS: 2.460750102996826
# epoch 1736: real_loss: [0.35010743, 0.59375]---fake_loss: [0.35614845, 0.375]---GAN_LOSS: 3.6214025020599365
# epoch 1737: real_loss: [0.32634807, 0.75]---fake_loss: [0.34083986, 0.59375]---GAN_LOSS: 2.7170469760894775
# epoch 1738: real_loss: [0.33912012, 0.625]---fake_loss: [0.33957398, 0.59375]---GAN_LOSS: 2.6949973106384277
# epoch 1739: real_loss: [0.3463686, 0.59375]---fake_loss: [0.33829218, 0.59375]---GAN_LOSS: 3.179513931274414
# epoch 1740: real_loss: [0.35524464, 0.5]---fake_loss: [0.333779, 0.65625]---GAN_LOSS: 2.481720447540283
# epoch 1741: real_loss: [0.34108755, 0.625]---fake_loss: [0.3546062, 0.4375]---GAN_LOSS: 2.557161808013916
# epoch 1742: real_loss: [0.33351567, 0.46875]---fake_loss: [0.3465404, 0.5625]---GAN_LOSS: 3.0183959007263184
# epoch 1743: real_loss: [0.33976224, 0.5]---fake_loss: [0.3392104, 0.59375]---GAN_LOSS: 2.7926340103149414
# epoch 1744: real_loss: [0.35331815, 0.40625]---fake_loss: [0.33347678, 0.625]---GAN_LOSS: 2.463327169418335
# epoch 1745: real_loss: [0.3512459, 0.5]---fake_loss: [0.33263075, 0.6875]---GAN_LOSS: 3.198899984359741
# epoch 1746: real_loss: [0.3406972, 0.625]---fake_loss: [0.3380841, 0.53125]---GAN_LOSS: 2.7761268615722656
# epoch 1747: real_loss: [0.34122807, 0.5625]---fake_loss: [0.3356626, 0.53125]---GAN_LOSS: 2.9369192123413086
# epoch 1748: real_loss: [0.34965694, 0.46875]---fake_loss: [0.34007612, 0.65625]---GAN_LOSS: 2.5221173763275146
# epoch 1749: real_loss: [0.35518193, 0.53125]---fake_loss: [0.33803344, 0.65625]---GAN_LOSS: 2.424379825592041
# epoch 1750: real_loss: [0.35042602, 0.59375]---fake_loss: [0.33630717, 0.59375]---GAN_LOSS: 2.9527053833007812
# epoch 1751: real_loss: [0.3386859, 0.65625]---fake_loss: [0.33867338, 0.5]---GAN_LOSS: 3.003295421600342
# epoch 1752: real_loss: [0.33818278, 0.5625]---fake_loss: [0.340043, 0.5625]---GAN_LOSS: 2.685032844543457
# epoch 1753: real_loss: [0.35147387, 0.65625]---fake_loss: [0.33881664, 0.65625]---GAN_LOSS: 2.695798873901367
# epoch 1754: real_loss: [0.3476964, 0.5625]---fake_loss: [0.33588165, 0.5625]---GAN_LOSS: 3.5295419692993164
# epoch 1755: real_loss: [0.34541744, 0.5]---fake_loss: [0.3342157, 0.625]---GAN_LOSS: 2.531602382659912
# epoch 1756: real_loss: [0.34578323, 0.59375]---fake_loss: [0.3378739, 0.5]---GAN_LOSS: 3.0269012451171875
# epoch 1757: real_loss: [0.34119463, 0.5625]---fake_loss: [0.33958057, 0.5625]---GAN_LOSS: 2.4186177253723145
# epoch 1758: real_loss: [0.330574, 0.71875]---fake_loss: [0.3450047, 0.5]---GAN_LOSS: 2.5145254135131836
# epoch 1759: real_loss: [0.33053845, 0.59375]---fake_loss: [0.34104365, 0.46875]---GAN_LOSS: 2.6840248107910156
# epoch 1760: real_loss: [0.3346435, 0.6875]---fake_loss: [0.3500473, 0.46875]---GAN_LOSS: 2.8319602012634277
# epoch 1761: real_loss: [0.3397825, 0.65625]---fake_loss: [0.33824724, 0.71875]---GAN_LOSS: 2.8611955642700195
# epoch 1762: real_loss: [0.35028267, 0.5]---fake_loss: [0.3435412, 0.5625]---GAN_LOSS: 3.0635342597961426
# epoch 1763: real_loss: [0.3500505, 0.53125]---fake_loss: [0.34786332, 0.4375]---GAN_LOSS: 2.483818531036377
# epoch 1764: real_loss: [0.33780217, 0.59375]---fake_loss: [0.3474137, 0.375]---GAN_LOSS: 3.477229356765747
# epoch 1765: real_loss: [0.34683052, 0.5625]---fake_loss: [0.33928394, 0.46875]---GAN_LOSS: 2.6912267208099365
# epoch 1766: real_loss: [0.3340609, 0.625]---fake_loss: [0.33981013, 0.5]---GAN_LOSS: 2.6686480045318604
# epoch 1767: real_loss: [0.34625316, 0.5625]---fake_loss: [0.33501035, 0.625]---GAN_LOSS: 3.4004344940185547
# epoch 1768: real_loss: [0.3343181, 0.5625]---fake_loss: [0.33609867, 0.625]---GAN_LOSS: 2.573727607727051
# epoch 1769: real_loss: [0.33621716, 0.625]---fake_loss: [0.34175992, 0.625]---GAN_LOSS: 2.7200493812561035
# epoch 1770: real_loss: [0.36916143, 0.375]---fake_loss: [0.32997757, 0.6875]---GAN_LOSS: 2.482271671295166
# epoch 1771: real_loss: [0.3388449, 0.59375]---fake_loss: [0.3381471, 0.5]---GAN_LOSS: 2.308201313018799
# epoch 1772: real_loss: [0.341057, 0.625]---fake_loss: [0.33907828, 0.59375]---GAN_LOSS: 2.6290860176086426
# epoch 1773: real_loss: [0.35078743, 0.46875]---fake_loss: [0.33541268, 0.59375]---GAN_LOSS: 2.6560401916503906
# epoch 1774: real_loss: [0.35181275, 0.5]---fake_loss: [0.33484235, 0.5625]---GAN_LOSS: 2.596334457397461
# epoch 1775: real_loss: [0.35145488, 0.53125]---fake_loss: [0.3436609, 0.59375]---GAN_LOSS: 2.8785815238952637
# epoch 1776: real_loss: [0.36618263, 0.46875]---fake_loss: [0.34790796, 0.53125]---GAN_LOSS: 2.57912540435791
# epoch 1777: real_loss: [0.3324178, 0.71875]---fake_loss: [0.32806003, 0.59375]---GAN_LOSS: 2.425266742706299
# epoch 1778: real_loss: [0.34597096, 0.5625]---fake_loss: [0.3380778, 0.65625]---GAN_LOSS: 2.5907070636749268
# epoch 1779: real_loss: [0.32543704, 0.78125]---fake_loss: [0.3343047, 0.59375]---GAN_LOSS: 2.54390025138855
# epoch 1780: real_loss: [0.33982223, 0.59375]---fake_loss: [0.3447751, 0.46875]---GAN_LOSS: 2.530412197113037
# epoch 1781: real_loss: [0.338372, 0.625]---fake_loss: [0.3410657, 0.5]---GAN_LOSS: 2.984257936477661
# epoch 1782: real_loss: [0.34730375, 0.65625]---fake_loss: [0.33379698, 0.65625]---GAN_LOSS: 2.824178695678711
# epoch 1783: real_loss: [0.35634315, 0.46875]---fake_loss: [0.3268027, 0.59375]---GAN_LOSS: 2.6525654792785645
# epoch 1784: real_loss: [0.32876986, 0.6875]---fake_loss: [0.3391558, 0.53125]---GAN_LOSS: 2.34106183052063
# epoch 1785: real_loss: [0.3351061, 0.59375]---fake_loss: [0.33094734, 0.71875]---GAN_LOSS: 2.4339890480041504
# epoch 1786: real_loss: [0.3631188, 0.46875]---fake_loss: [0.33502853, 0.53125]---GAN_LOSS: 2.739434003829956
# epoch 1787: real_loss: [0.35099483, 0.5625]---fake_loss: [0.3363306, 0.59375]---GAN_LOSS: 2.5009071826934814
# epoch 1788: real_loss: [0.34349915, 0.53125]---fake_loss: [0.35799992, 0.4375]---GAN_LOSS: 3.0352442264556885
# epoch 1789: real_loss: [0.33725578, 0.6875]---fake_loss: [0.31863344, 0.75]---GAN_LOSS: 2.6326651573181152
# epoch 1790: real_loss: [0.37235606, 0.34375]---fake_loss: [0.33350158, 0.625]---GAN_LOSS: 3.0355379581451416
# epoch 1791: real_loss: [0.35445976, 0.375]---fake_loss: [0.32886457, 0.5625]---GAN_LOSS: 2.8126442432403564
# epoch 1792: real_loss: [0.35725516, 0.375]---fake_loss: [0.33967227, 0.5625]---GAN_LOSS: 2.8477513790130615
# epoch 1793: real_loss: [0.33391237, 0.65625]---fake_loss: [0.33351147, 0.59375]---GAN_LOSS: 3.672555923461914
# epoch 1794: real_loss: [0.33620745, 0.75]---fake_loss: [0.34467107, 0.53125]---GAN_LOSS: 2.8778188228607178
# epoch 1795: real_loss: [0.32498688, 0.6875]---fake_loss: [0.33522147, 0.5625]---GAN_LOSS: 2.920949697494507
# epoch 1796: real_loss: [0.34546867, 0.59375]---fake_loss: [0.3374974, 0.53125]---GAN_LOSS: 2.7790348529815674
# epoch 1797: real_loss: [0.33644557, 0.625]---fake_loss: [0.3353992, 0.59375]---GAN_LOSS: 2.3399243354797363
# epoch 1798: real_loss: [0.3360428, 0.65625]---fake_loss: [0.33068883, 0.59375]---GAN_LOSS: 2.5594539642333984
# epoch 1799: real_loss: [0.35987085, 0.40625]---fake_loss: [0.35352403, 0.53125]---GAN_LOSS: 2.9294633865356445
# epoch 1800: real_loss: [0.36252397, 0.4375]---fake_loss: [0.33430487, 0.71875]---GAN_LOSS: 3.0762929916381836
# epoch 1801: real_loss: [0.34277505, 0.5625]---fake_loss: [0.34045783, 0.46875]---GAN_LOSS: 2.4227452278137207
# epoch 1802: real_loss: [0.32206225, 0.71875]---fake_loss: [0.33142793, 0.65625]---GAN_LOSS: 2.641575336456299
# epoch 1803: real_loss: [0.35071558, 0.5]---fake_loss: [0.3306809, 0.6875]---GAN_LOSS: 2.37092661857605
# epoch 1804: real_loss: [0.34124282, 0.625]---fake_loss: [0.34718174, 0.46875]---GAN_LOSS: 2.9752116203308105
# epoch 1805: real_loss: [0.35270905, 0.53125]---fake_loss: [0.3350643, 0.625]---GAN_LOSS: 2.5770678520202637
# epoch 1806: real_loss: [0.32849163, 0.78125]---fake_loss: [0.34122372, 0.59375]---GAN_LOSS: 2.599344491958618
# epoch 1807: real_loss: [0.33567482, 0.59375]---fake_loss: [0.3330776, 0.53125]---GAN_LOSS: 3.5811493396759033
# epoch 1808: real_loss: [0.3389579, 0.625]---fake_loss: [0.33066627, 0.6875]---GAN_LOSS: 2.38932466506958
# epoch 1809: real_loss: [0.34820962, 0.59375]---fake_loss: [0.33549583, 0.65625]---GAN_LOSS: 3.0004239082336426
# epoch 1810: real_loss: [0.33491343, 0.6875]---fake_loss: [0.33069876, 0.59375]---GAN_LOSS: 2.1639952659606934
# epoch 1811: real_loss: [0.33812773, 0.59375]---fake_loss: [0.34514737, 0.59375]---GAN_LOSS: 2.4932618141174316
# epoch 1812: real_loss: [0.34577376, 0.59375]---fake_loss: [0.33962423, 0.59375]---GAN_LOSS: 2.8359551429748535
# epoch 1813: real_loss: [0.35912508, 0.5]---fake_loss: [0.3344012, 0.59375]---GAN_LOSS: 2.721832275390625
# epoch 1814: real_loss: [0.34133545, 0.59375]---fake_loss: [0.34095955, 0.5]---GAN_LOSS: 2.2017180919647217
# epoch 1815: real_loss: [0.32081202, 0.71875]---fake_loss: [0.33415997, 0.59375]---GAN_LOSS: 2.6295058727264404
# epoch 1816: real_loss: [0.33625036, 0.625]---fake_loss: [0.34344095, 0.5625]---GAN_LOSS: 2.71376895904541
# epoch 1817: real_loss: [0.33995432, 0.46875]---fake_loss: [0.33951676, 0.46875]---GAN_LOSS: 2.3673136234283447
# epoch 1818: real_loss: [0.3490231, 0.5625]---fake_loss: [0.32868484, 0.59375]---GAN_LOSS: 2.32789945602417
# epoch 1819: real_loss: [0.34615612, 0.6875]---fake_loss: [0.3385415, 0.53125]---GAN_LOSS: 2.878934383392334
# epoch 1820: real_loss: [0.35286528, 0.53125]---fake_loss: [0.32985923, 0.65625]---GAN_LOSS: 2.967979907989502
# epoch 1821: real_loss: [0.33251, 0.71875]---fake_loss: [0.3372069, 0.5625]---GAN_LOSS: 2.80549693107605
# epoch 1822: real_loss: [0.3394096, 0.5625]---fake_loss: [0.3353756, 0.53125]---GAN_LOSS: 2.4289236068725586
# epoch 1823: real_loss: [0.35055923, 0.4375]---fake_loss: [0.3341148, 0.5]---GAN_LOSS: 3.7228362560272217
# epoch 1824: real_loss: [0.35068557, 0.53125]---fake_loss: [0.33149925, 0.625]---GAN_LOSS: 2.6807990074157715
# epoch 1825: real_loss: [0.3442278, 0.5]---fake_loss: [0.34647, 0.53125]---GAN_LOSS: 2.2991349697113037
# epoch 1826: real_loss: [0.34872457, 0.46875]---fake_loss: [0.33334333, 0.59375]---GAN_LOSS: 2.5043959617614746
# epoch 1827: real_loss: [0.3352177, 0.625]---fake_loss: [0.32574, 0.59375]---GAN_LOSS: 3.2481744289398193
# epoch 1828: real_loss: [0.34779066, 0.46875]---fake_loss: [0.32663345, 0.5625]---GAN_LOSS: 2.89937686920166
# epoch 1829: real_loss: [0.33204228, 0.75]---fake_loss: [0.3430671, 0.59375]---GAN_LOSS: 3.062394618988037
# epoch 1830: real_loss: [0.34246278, 0.59375]---fake_loss: [0.32941532, 0.59375]---GAN_LOSS: 2.321495294570923
# epoch 1831: real_loss: [0.32422808, 0.71875]---fake_loss: [0.33732545, 0.625]---GAN_LOSS: 2.3614606857299805
# epoch 1832: real_loss: [0.3541202, 0.40625]---fake_loss: [0.3340341, 0.53125]---GAN_LOSS: 2.84863543510437
# epoch 1833: real_loss: [0.34489727, 0.59375]---fake_loss: [0.35499173, 0.46875]---GAN_LOSS: 2.907911539077759
# epoch 1834: real_loss: [0.33542258, 0.71875]---fake_loss: [0.34262213, 0.46875]---GAN_LOSS: 2.893622398376465
# epoch 1835: real_loss: [0.32692128, 0.78125]---fake_loss: [0.3488371, 0.53125]---GAN_LOSS: 3.746792793273926
# epoch 1836: real_loss: [0.339214, 0.5]---fake_loss: [0.333681, 0.625]---GAN_LOSS: 3.612330675125122
# epoch 1837: real_loss: [0.3428691, 0.53125]---fake_loss: [0.3286472, 0.625]---GAN_LOSS: 2.780221939086914
# epoch 1838: real_loss: [0.36276737, 0.34375]---fake_loss: [0.33027685, 0.65625]---GAN_LOSS: 3.1048340797424316
# epoch 1839: real_loss: [0.34625193, 0.4375]---fake_loss: [0.33204028, 0.75]---GAN_LOSS: 2.727332592010498
# epoch 1840: real_loss: [0.33980018, 0.625]---fake_loss: [0.33656698, 0.65625]---GAN_LOSS: 2.9861795902252197
# epoch 1841: real_loss: [0.33518046, 0.65625]---fake_loss: [0.32805628, 0.65625]---GAN_LOSS: 2.3506715297698975
# epoch 1842: real_loss: [0.3375432, 0.625]---fake_loss: [0.33248848, 0.59375]---GAN_LOSS: 2.6123030185699463
# epoch 1843: real_loss: [0.3275457, 0.6875]---fake_loss: [0.3314342, 0.5625]---GAN_LOSS: 2.514004707336426
# epoch 1844: real_loss: [0.34410244, 0.53125]---fake_loss: [0.34054118, 0.59375]---GAN_LOSS: 2.837322235107422
# epoch 1845: real_loss: [0.3475657, 0.59375]---fake_loss: [0.3466096, 0.5]---GAN_LOSS: 2.4098470211029053
# epoch 1846: real_loss: [0.35855803, 0.46875]---fake_loss: [0.33467183, 0.625]---GAN_LOSS: 2.3672173023223877
# epoch 1847: real_loss: [0.32821277, 0.71875]---fake_loss: [0.34041727, 0.65625]---GAN_LOSS: 2.41621732711792
# epoch 1848: real_loss: [0.35784572, 0.34375]---fake_loss: [0.3276908, 0.625]---GAN_LOSS: 2.665719985961914
# epoch 1849: real_loss: [0.32421437, 0.6875]---fake_loss: [0.3440768, 0.59375]---GAN_LOSS: 2.2693963050842285
# epoch 1850: real_loss: [0.33839583, 0.65625]---fake_loss: [0.3309992, 0.59375]---GAN_LOSS: 3.6452345848083496
# epoch 1851: real_loss: [0.34538206, 0.59375]---fake_loss: [0.32916644, 0.59375]---GAN_LOSS: 2.8556246757507324
# epoch 1852: real_loss: [0.35437012, 0.46875]---fake_loss: [0.3364318, 0.53125]---GAN_LOSS: 2.1838555335998535
# epoch 1853: real_loss: [0.3336292, 0.71875]---fake_loss: [0.34124005, 0.59375]---GAN_LOSS: 2.8458051681518555
# epoch 1854: real_loss: [0.3490308, 0.59375]---fake_loss: [0.3289703, 0.65625]---GAN_LOSS: 2.402137279510498
# epoch 1855: real_loss: [0.34103477, 0.5625]---fake_loss: [0.33955207, 0.46875]---GAN_LOSS: 2.8743269443511963
# epoch 1856: real_loss: [0.35799518, 0.46875]---fake_loss: [0.33187363, 0.59375]---GAN_LOSS: 2.9243998527526855
# epoch 1857: real_loss: [0.3319214, 0.6875]---fake_loss: [0.3379074, 0.5625]---GAN_LOSS: 3.272329330444336
# epoch 1858: real_loss: [0.3307994, 0.6875]---fake_loss: [0.3357167, 0.65625]---GAN_LOSS: 2.7253050804138184
# epoch 1859: real_loss: [0.33941174, 0.625]---fake_loss: [0.33058012, 0.65625]---GAN_LOSS: 3.1401095390319824
# epoch 1860: real_loss: [0.34522837, 0.5]---fake_loss: [0.33020023, 0.65625]---GAN_LOSS: 2.452314853668213
# epoch 1861: real_loss: [0.3377907, 0.5625]---fake_loss: [0.3405739, 0.59375]---GAN_LOSS: 2.4423105716705322
# epoch 1862: real_loss: [0.33523118, 0.65625]---fake_loss: [0.34514877, 0.5625]---GAN_LOSS: 2.4452085494995117
# epoch 1863: real_loss: [0.3445992, 0.59375]---fake_loss: [0.33618033, 0.625]---GAN_LOSS: 2.3183233737945557
# epoch 1864: real_loss: [0.34664214, 0.625]---fake_loss: [0.33836013, 0.5625]---GAN_LOSS: 2.6200900077819824
# epoch 1865: real_loss: [0.33944425, 0.6875]---fake_loss: [0.33328855, 0.6875]---GAN_LOSS: 2.9595746994018555
# epoch 1866: real_loss: [0.32023498, 0.75]---fake_loss: [0.32831648, 0.59375]---GAN_LOSS: 2.6408708095550537
# epoch 1867: real_loss: [0.33299667, 0.71875]---fake_loss: [0.3316727, 0.59375]---GAN_LOSS: 2.258793830871582
# epoch 1868: real_loss: [0.34115607, 0.65625]---fake_loss: [0.33482242, 0.5625]---GAN_LOSS: 2.811258316040039
# epoch 1869: real_loss: [0.3362797, 0.65625]---fake_loss: [0.33303106, 0.5]---GAN_LOSS: 2.684016227722168
# epoch 1870: real_loss: [0.33986524, 0.5625]---fake_loss: [0.33129686, 0.65625]---GAN_LOSS: 2.6156210899353027
# epoch 1871: real_loss: [0.34271044, 0.625]---fake_loss: [0.3381307, 0.5625]---GAN_LOSS: 2.472954511642456
# epoch 1872: real_loss: [0.348702, 0.5]---fake_loss: [0.33232623, 0.6875]---GAN_LOSS: 2.2178869247436523
# epoch 1873: real_loss: [0.32996857, 0.65625]---fake_loss: [0.33293825, 0.65625]---GAN_LOSS: 2.9296092987060547
# epoch 1874: real_loss: [0.3363685, 0.6875]---fake_loss: [0.32921427, 0.59375]---GAN_LOSS: 2.755998373031616
# epoch 1875: real_loss: [0.33520275, 0.53125]---fake_loss: [0.34113714, 0.53125]---GAN_LOSS: 2.6964025497436523

# %%
a = np.random.randint(1,32)
i = real_print[a]
j = np.reshape(i,(28,28))
plt.subplot(1,3,1)
plt.imshow(j,cmap='gray')
i = real_hand[a]
j = np.reshape(i,(28,28))
plt.subplot(1,3,2)
plt.imshow(j,cmap='gray')
i = fake_print[a]
j = np.reshape(i,(28,28))
plt.subplot(1,3,3)
plt.imshow(j,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-6fe3342bea2e> in <module>
#      13 plt.imshow(j,cmap='gray')
#      14 plt.show()
# ---> 15 plt.savefig("aaa.png")
#      16 plt.close()
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     519
#     520         with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
#     523                             self.figure.dpi, metadata=metadata)
#
# /opt/conda/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     405 def open_file_cm(path_or_file, mode="r", encoding=None):
#     406     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 407     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     408     if opened:
#     409         with fh:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     390             fh = bz2.BZ2File(fname, flag)
#     391         else:
# --> 392             fh = open(fname, flag, encoding=encoding)
#     393         opened = True
#     394     elif hasattr(fname, 'seek'):
#
# OSError: [Errno 30] Read-only file system: 'aaa.png'
