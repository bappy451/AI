# %% [markdown]
# # This program is for practic and plotting model
# ## in this program I used make_moons and Logistic Regresstion & Deep Neural Net
# ### plotted both model
# ### saved model and weight and loaded that model and weight

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras
import os
# Out:
# Using TensorFlow backend.

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# %%
X,y = make_moons(n_samples=1000, noise=0.1)
plt.plot(X[y==0,0],X[y==0,1],'ob',alpha = 0.5)
plt.plot(X[y==1,0],X[y==1,1],'xr',alpha = 0.5)
plt.legend(['0','1'])
X.shape
# Out:
# (1000, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   test_size = 0.3,
                                                   random_state = 42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam

# %%
model = Sequential()
model.add(Dense(1,input_shape=(2,),activation='sigmoid'))
model.compile(Adam(0.01),'binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.fit(X_train,y_train,epochs=100, verbose=0)
# Out:
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.

# %%
result = model.evaluate(X_test,y_test,verbose=1)
# Out:
# 300/300 [==============================] - 0s 490us/step

# %%
print("the accuracy is {:0.3f}".format(result[1]))
# Out:
# the accuracy is 0.910

# %%
def plot_decision_boundary(model,X,y):
    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb. ravel()]
    
    c = model.predict(ab)
    cc = c.reshape(aa.shape)
    
    plt.figure(figsize=(12,8))
    plt.contourf(aa,bb,cc, cmap='bwr', alpha=0.2)
    plt.plot(X[y==0,0],X[y==0,1],'ob',alpha = 0.5)
    plt.plot(X[y==1,0],X[y==1,1],'xr',alpha = 0.5)
    plt.legend(['0','1'])

plot_decision_boundary(model,X,y)

# %%
deep_model = Sequential()
deep_model.add(Dense(4, input_shape=(2,), activation='tanh',name='layer1'))
deep_model.add(Dense(3,activation='tanh',name='layer2'))
deep_model.add(Dense(1,activation='sigmoid',name='outputLayer'))
deep_model.compile(Adam(0.01), 'binary_crossentropy', metrics=['accuracy'])
deep_model.summary
# Out:
# <bound method Network.summary of <keras.engine.sequential.Sequential object at 0x00000210226EA7F0>>

# %%
logger = keras.callbacks.TensorBoard(
                        log_dir="logsPlotting",
                        write_graph=True,
                        histogram_freq=5)

# %%
deep_model.fit(X_train,y_train,epochs=50, shuffle=True,verbose=1,callbacks=[logger], validation_data=(X_test,y_test))
# Out:
# Train on 700 samples, validate on 300 samples
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\callbacks.py:796: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\Tara\Anaconda3\envs\tensorflow_env\lib\site-packages\keras\callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/50
# 700/700 [==============================] - 1s 2ms/step - loss: 0.6084 - acc: 0.7471 - val_loss: 0.5053 - val_acc: 0.8567
# Epoch 2/50
# 700/700 [==============================] - 0s 79us/step - loss: 0.4726 - acc: 0.8243 - val_loss: 0.3961 - val_acc: 0.8833
# Epoch 3/50
# 700/700 [==============================] - 0s 77us/step - loss: 0.3862 - acc: 0.8543 - val_loss: 0.3181 - val_acc: 0.9133
# Epoch 4/50
# 700/700 [==============================] - 0s 74us/step - loss: 0.3307 - acc: 0.8786 - val_loss: 0.2738 - val_acc: 0.9133
# Epoch 5/50
# 700/700 [==============================] - 0s 81us/step - loss: 0.3060 - acc: 0.8829 - val_loss: 0.2552 - val_acc: 0.9100
# Epoch 6/50
# 700/700 [==============================] - 0s 90us/step - loss: 0.2959 - acc: 0.8771 - val_loss: 0.2486 - val_acc: 0.9067
# Epoch 7/50
# 700/700 [==============================] - 0s 71us/step - loss: 0.2915 - acc: 0.8829 - val_loss: 0.2439 - val_acc: 0.9133
# Epoch 8/50
# 700/700 [==============================] - 0s 79us/step - loss: 0.2922 - acc: 0.8771 - val_loss: 0.2445 - val_acc: 0.9000
# Epoch 9/50
# 700/700 [==============================] - 0s 69us/step - loss: 0.2977 - acc: 0.8700 - val_loss: 0.2423 - val_acc: 0.9000
# Epoch 10/50
# 700/700 [==============================] - 0s 94us/step - loss: 0.2834 - acc: 0.8814 - val_loss: 0.2406 - val_acc: 0.9000
# Epoch 11/50
# 700/700 [==============================] - 0s 71us/step - loss: 0.2884 - acc: 0.8757 - val_loss: 0.2400 - val_acc: 0.8967
# Epoch 12/50
# 700/700 [==============================] - 0s 69us/step - loss: 0.2834 - acc: 0.8814 - val_loss: 0.2353 - val_acc: 0.9133
# Epoch 13/50
# 700/700 [==============================] - 0s 101us/step - loss: 0.2805 - acc: 0.8800 - val_loss: 0.2365 - val_acc: 0.9000
# Epoch 14/50
# 700/700 [==============================] - 0s 76us/step - loss: 0.2814 - acc: 0.8743 - val_loss: 0.2341 - val_acc: 0.9033
# Epoch 15/50
# 700/700 [==============================] - 0s 86us/step - loss: 0.2772 - acc: 0.8857 - val_loss: 0.2318 - val_acc: 0.9100
# Epoch 16/50
# 700/700 [==============================] - 0s 81us/step - loss: 0.2762 - acc: 0.8786 - val_loss: 0.2312 - val_acc: 0.9067
# Epoch 17/50
# 700/700 [==============================] - 0s 80us/step - loss: 0.2769 - acc: 0.8800 - val_loss: 0.2296 - val_acc: 0.9133
# Epoch 18/50
# Epoch 37/50
# 700/700 [==============================] - 0s 67us/step - loss: 0.0626 - acc: 0.9886 - val_loss: 0.0474 - val_acc: 0.9933
# Epoch 38/50
# 700/700 [==============================] - 0s 70us/step - loss: 0.0512 - acc: 0.9900 - val_loss: 0.0373 - val_acc: 0.9900
# Epoch 39/50
# 700/700 [==============================] - 0s 70us/step - loss: 0.0422 - acc: 0.9914 - val_loss: 0.0306 - val_acc: 0.9933
# Epoch 40/50
# 700/700 [==============================] - 0s 69us/step - loss: 0.0362 - acc: 0.9943 - val_loss: 0.0260 - val_acc: 1.0000
# Epoch 41/50
# 700/700 [==============================] - 0s 70us/step - loss: 0.0315 - acc: 0.9971 - val_loss: 0.0264 - val_acc: 0.9933
# Epoch 42/50
# 700/700 [==============================] - 0s 70us/step - loss: 0.0310 - acc: 0.9957 - val_loss: 0.0209 - val_acc: 1.0000
# Epoch 43/50
# 700/700 [==============================] - 0s 86us/step - loss: 0.0257 - acc: 0.9971 - val_loss: 0.0189 - val_acc: 1.0000
# Epoch 44/50
# 700/700 [==============================] - 0s 66us/step - loss: 0.0235 - acc: 0.9943 - val_loss: 0.0173 - val_acc: 1.0000
# Epoch 45/50
# 700/700 [==============================] - 0s 83us/step - loss: 0.0211 - acc: 0.9957 - val_loss: 0.0149 - val_acc: 1.0000
# Epoch 46/50
# 700/700 [==============================] - 0s 71us/step - loss: 0.0196 - acc: 0.9971 - val_loss: 0.0131 - val_acc: 1.0000
# Epoch 47/50
# 700/700 [==============================] - 0s 71us/step - loss: 0.0195 - acc: 0.9971 - val_loss: 0.0122 - val_acc: 1.0000
# Epoch 48/50
# 700/700 [==============================] - 0s 70us/step - loss: 0.0178 - acc: 0.9971 - val_loss: 0.0126 - val_acc: 1.0000
# Epoch 49/50
# 700/700 [==============================] - 0s 81us/step - loss: 0.0167 - acc: 0.9957 - val_loss: 0.0117 - val_acc: 1.0000
# Epoch 50/50
# 700/700 [==============================] - 0s 91us/step - loss: 0.0177 - acc: 0.9971 - val_loss: 0.0099 - val_acc: 1.0000

# %%
deep_model.evaluate(X_test,y_test,verbose=1)
# Out:
# 300/300 [==============================] - 0s 103us/step
# [0.009930937048047782, 1.0]

# %%
plot_decision_boundary(deep_model,X,y)

# %%
mode_jeson = deep_model.to_json()

# %%
with open("model_pima.json","w") as json_file:
    json_file.write(mode_jeson)

# %%
deep_model.save_weights("model_pima.h5")

# %%
from keras.models import model_from_json

# %%
json_file = open('model_pima.json','r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
loaded_model.load_weights("model_pima.h5")

# %%
loaded_model.compile(Adam(0.01), 'binary_crossentropy', metrics=['accuracy'])

# %%
loaded_model.evaluate(X_test,y_test,verbose=1)
# Out:
# 300/300 [==============================] - 0s 826us/step
# [0.009930937048047782, 1.0]
